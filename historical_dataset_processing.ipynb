# %% [markdown]
# <a href="https://colab.research.google.com/github/derek881107/Real-Time-Disaster-Detection-System/blob/main/historical_dataset_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ===============================================================================
# Historical Disaster–Client Proximity Analyzer (GDACS + GeoSpatial)
# ===============================================================================
#
#
# Overview
# --------
# This script builds a precise, geometry-aware pipeline to detect which client
# locations may be affected by historical disaster events reported by GDACS.
# Instead of relying on coarse bounding boxes, it fetches and unifies per-episode
# polygons from the GDACS API, buffers them if requested, and computes the exact
# shortest distance from each client point to each disaster geometry. Results are
# exported to both JSON (summary + matches) and a multi-sheet Excel workbook for
# analysis and reporting.
#
# Typical Use Cases
# -----------------
# - Quantify which client sites fell within X km of historical disasters.
# - Produce decision-ready spreadsheets and JSON summaries for risk reviews.
# - Merge multiple GDACS GeoJSON files and de-duplicate events by ID.
# - Convert merged GeoJSON to a flat CSV for quick inspection.
#
# Key Inputs
# ----------
# 1) Client CSV (required)
#    - A table of client/vendor/facility locations.
#    - Expected columns (case-insensitive; extra columns are OK):
#      - id, name, address, country, type, latitude, longitude
#      - latitude and longitude must be numeric (WGS84).
#
# 2) GDACS GeoJSON (required)
#    - A merged GeoJSON of disaster events (features list) with rich `properties`,
#      including `eventid`, `eventtype`, `name`, `description`, `fromdate`,
#      `todate`, `alertlevel`, and `url.details`.
#    - The script can help you:
#        • merge many *.geojson/*.json files: `merge_geojson_files(...)`
#        • auto-discover & merge by pattern: `auto_merge_json_files(...)`
#        • remove duplicate events by a key (default `eventid`)
#
# Core Workflow (What the Script Does)
# ------------------------------------
# 1) Data Prep
#    - Optionally merge multiple GDACS GeoJSON files and drop duplicates.
#    - (Optional) Convert merged GeoJSON to CSV for a flat preview.
#
# 2) Geometry Enrichment (per disaster event)
#    - Use `properties.url.details` to fetch the event’s episode list.
#    - For each episode, call the GDACS polygons API to retrieve geometries.
#    - Validate and fix geometries if needed; unify (union) all episode shapes
#      into one “event geometry.” Optionally apply a buffer (km → degrees).
#
# 3) Proximity Analysis (per client point)
#    - Compute the shortest distance from the client’s (lon, lat) to the unified
#      event geometry. If the point lies inside the polygon, distance = 0.
#    - Keep matches within a user-defined threshold (e.g., 50, 100, 200 km).
#
# 4) Reporting & Export
#    - JSON: overall stats + geometry summary + full match records.
#    - Excel: a comprehensive workbook with multiple analysis sheets, including:
#        • Matches (row-level results with client + disaster context)
#        • Summary_Statistics (totals, uniques, distance stats)
#        • Disaster_Types (counts + percentages)
#        • Alert_Levels (counts + percentages)
#        • Countries_Affected (client-country perspective)
#        • Distance_Analysis (0–10, 10–50, 50–100, 100–200, >200 km bins)
#        • All_Disaster_Events (complete GDACS properties per event)
#        • Geometry_Summary (event-level geometry metadata)
#
# Primary Functions (What to Call)
# --------------------------------
# - merge_geojson_files(file_paths, output_filename)
#     Merge many GeoJSON/JSON files into one FeatureCollection.
#
# - geojson_to_csv(geojson_data, output_filename)
#     Flatten a FeatureCollection to CSV (geometry basics + properties).
#
# - remove_duplicates(geojson_data, key_field='eventid')
#     Drop duplicate features by a chosen properties key.
#
# - fetch_event_episodes(event_data)
#     From the event details URL, retrieve all associated episode IDs.
#
# - fetch_episode_geometry(event_type, event_id, episode_id)
#     Download the polygon(s)/point(s) for a specific episode from GDACS.
#
# - create_unified_event_geometry(event_data, buffer_km=0)
#     Union all episode geometries; optional km-buffer; return shape + bbox + GeoJSON.
#
# - point_to_geometry_distance(lon, lat, geometry)
#     Compute the shortest distance (km) from a point to a Shapely geometry.
#
# - analyze_disaster_proximity_enhanced(csv_file_path, json_file_path,
#                                       max_distance_km, buffer_km=0,
#                                       cache_geometries=True)
#     End-to-end engine: read inputs, build/cached geometries, compute matches.
#
# - save_enhanced_results(results, geometry_cache, output_file='.json')
#     Persist JSON with analysis summary, geometry summary, and all matches.
#
# - save_results_to_excel(results, geometry_cache, output_file='.xlsx')
#     Produce the multi-sheet Excel workbook described above.
#
# - export_geometries_geojson(geometry_cache, output_file='.geojson')
#     Write unified event geometries to a standalone GeoJSON.
#
# - interactive_enhanced_setup() / main_enhanced()
#     Guided prompts (useful in Colab) to choose files and distances.
#
# - quick_enhanced_analysis(csv_path=None, json_path=None)
#     Fast path for running the enhanced analysis with minimal prompts.
#
# Outputs & File Naming
# ---------------------
# - JSON:  enhanced_disaster_analysis_{DIST}km_buffer{BUFFER}km.json
# - Excel: enhanced_disaster_analysis_{DIST}km_buffer{BUFFER}km.xlsx
# - Merged GeoJSON: user-specified name (e.g., merged_geojson.json)
# - Optional CSV from GeoJSON: user-specified name (e.g., merged_data.csv)
#
# Distance & Buffer Notes
# -----------------------
# - Distances are computed using Shapely geometry distances converted from
#   degrees to kilometers with the factor ≈ 111.32 km/degree. This is a practical,
#   widely used approximation. For very large distances or near the poles, consider
#   swapping in a true geodesic approach if you need higher fidelity.
# - Buffering uses the same conversion (km → degrees) before applying
#   `geometry.buffer(...)`.
#
# Dependencies
# ------------
# - Python 3.9+
# - Packages: pandas, numpy, shapely, requests, openpyxl
#   Install example: `pip install pandas numpy shapely requests openpyxl`
#
# Runtime & Environment
# ---------------------
# - Internet access is required to call GDACS APIs when constructing geometries.
# - Works in local Python and Google Colab; Colab file-upload helpers are included.
# - A geometry cache prevents refetching for the same event during a run.
#
# Typical Usage
# -------------
# A) Quick run with saved files:
#    1) Prepare: a client CSV + a merged GDACS GeoJSON.
#    2) Call:    `results, cache = quick_enhanced_analysis('/path/clients.csv',
#                                                          '/path/merged_geojson.json')`
#    3) Choose a maximum distance (e.g., 100 km) and an optional buffer (e.g., 10 km).
#    4) Save JSON/Excel when prompted.
#
# B) Interactive (helpful in Colab):
#    1) Run `main_enhanced()`
#    2) Follow prompts to pick files, set distances, and export artifacts.
#
# Error Handling & Validation
# ---------------------------
# - Invalid polygons are repaired with `buffer(0)` when possible.
# - Episode fetch failures fall back to the current episode ID.
# - Client coordinate parsing is guarded; malformed rows are skipped with a warning.
# - If required columns are missing, the script reports a clear message and aborts.
#
# Assumptions & Limitations
# -------------------------
# - Client CSV must include valid latitude/longitude.
# - GDACS GeoJSON must include the properties needed to discover details/episodes.
# - Distance conversion uses a fixed km/degree factor; use geodesic libraries if
#   you require sub-kilometer accuracy at high latitudes or over large spans.
#
# License & Attribution
# ---------------------
# This script consumes publicly available GDACS data/APIs. Please respect their
# usage guidelines and attribute GDACS in downstream analyses or reports.
#
# Last updated: 2025-09-06

# %%
import json
import pandas as pd
import os
from collections import defaultdict
import glob

def merge_geojson_files(file_paths, output_filename='merged_geojson.json'):
    """
    Merge multiple GeoJSON files into one large GeoJSON file
    """
    merged_features = []
    all_bbox = []

    for file_path in file_paths:
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)

            if 'features' in data:
                merged_features.extend(data['features'])
                print(f"Processed {file_path}: {len(data['features'])} features")

                if data.get('bbox'):
                    all_bbox.append(data['bbox'])

        except Exception as e:
            print(f"Error processing {file_path}: {e}")

    merged_geojson = {
        "type": "FeatureCollection",
        "features": merged_features,
        "bbox": None
    }


    with open(output_filename, 'w', encoding='utf-8') as f:
        json.dump(merged_geojson, f, ensure_ascii=False, indent=2)

    print(f"Merge completed! Total {len(merged_features)} features")
    print(f"Saved as: {output_filename}")

    return merged_geojson


def geojson_to_csv(geojson_data, output_filename='merged_data.csv'):
    """
    Convert GeoJSON data to CSV format
    """
    rows = []

    for feature in geojson_data['features']:
        row = {}

        geometry = feature.get('geometry', {})
        if geometry.get('type') == 'Point':
            coordinates = geometry.get('coordinates', [])
            if len(coordinates) >= 2:
                row['longitude'] = coordinates[0]
                row['latitude'] = coordinates[1]

        properties = feature.get('properties', {})
        for key, value in properties.items():
            if isinstance(value, (str, int, float, bool)):
                row[key] = value
            elif isinstance(value, list) and key == 'affectedcountries':
                country_names = [country.get('countryname', '') for country in value]
                row[f'{key}_names'] = '; '.join(country_names)
                country_codes = [country.get('iso3', '') for country in value]
                row[f'{key}_codes'] = '; '.join(country_codes)
            elif isinstance(value, dict):
                for sub_key, sub_value in value.items():
                    if isinstance(sub_value, (str, int, float, bool)):
                        row[f'{key}_{sub_key}'] = sub_value
            else:
                row[key] = str(value)

        rows.append(row)

    df = pd.DataFrame(rows)
    df.to_csv(output_filename, index=False, encoding='utf-8')

    print(f"CSV file saved as: {output_filename}")
    print(f"Contains {len(df)} rows of data, {len(df.columns)} columns")

    return df

def auto_merge_json_files(folder_path='.', pattern='*.json'):



    json_files = glob.glob(os.path.join(folder_path, pattern))

    if not json_files:
        print("No JSON files found")
        return None

    print(f"Found {len(json_files)} JSON files:")
    for file in json_files:
        print(f"  - {file}")

    return merge_geojson_files(json_files)

# Main execution program
def main():
    print("=== JSON File Merger Program ===\n")

    # Option 1: Manually specify file paths
    # Please replace these paths with your actual file paths
    file_paths = [
        'China.geojson',
        'India.geojson',
        'Malaysia.geojson',
        'Mexico.geojson',
        'Netherlands.geojson',
        'Romania.geojson',
        'United States.geojson'
    ]

    # Check if files exist
    existing_files = [f for f in file_paths if os.path.exists(f)]

    if not existing_files:
        print("Manually specified files do not exist, trying automatic search...")
        # Option 2: Automatically search for all JSON files in current directory
        merged_data = auto_merge_json_files()
    else:
        print(f"Found {len(existing_files)} files, starting merge...")
        merged_data = merge_geojson_files(existing_files)

    if merged_data:
        # Also generate CSV file
        print("\nConverting to CSV format...")
        df = geojson_to_csv(merged_data)

        # Display data summary
        print(f"\n=== Data Summary ===")
        print(f"Total number of features: {len(merged_data['features'])}")
        if not df.empty:
            print(f"Number of CSV columns: {len(df.columns)}")
            print(f"Main columns: {list(df.columns[:10])}")

            # Display event type statistics
            if 'eventtype' in df.columns:
                event_counts = df['eventtype'].value_counts()
                print(f"\nEvent type statistics:")
                for event_type, count in event_counts.items():
                    print(f"  {event_type}: {count}")

            # Display country statistics
            if 'country' in df.columns:
                country_counts = df['country'].value_counts().head(10)
                print(f"\nTop 10 countries/regions:")
                for country, count in country_counts.items():
                    print(f"  {country}: {count}")

# Execute program
if __name__ == "__main__":
    main()

# Additional feature: Remove duplicate data
def remove_duplicates(geojson_data, key_field='eventid'):
    """
    Remove duplicate features based on specified field
    """
    seen_keys = set()
    unique_features = []

    for feature in geojson_data['features']:
        key_value = feature.get('properties', {}).get(key_field)
        if key_value not in seen_keys:
            seen_keys.add(key_value)
            unique_features.append(feature)
        else:
            print(f"Found duplicate data: {key_field} = {key_value}")

    geojson_data['features'] = unique_features
    print(f"After removing duplicates, {len(unique_features)} features remaining")

    return geojson_data

# Usage example:
# If you want to remove duplicate data, you can use it like this:
# merged_data = remove_duplicates(merged_data, 'eventid')
# Out:
# === JSON File Merger Program ===
#
# Manually specified files do not exist, trying automatic search...
# No JSON files found

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Enhanced Disaster Location Analysis Tool
Compare CSV client locations with precise GeoJSON disaster geometries
Uses actual polygon shapes instead of simple bounding boxes
"""

import pandas as pd
import json
import numpy as np
from math import radians, cos, sin, asin, sqrt
import sys
import os
import requests
import time
from shapely.geometry import Point, Polygon, MultiPolygon, shape
from shapely.ops import unary_union
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

def haversine_distance(lon1, lat1, lon2, lat2):
    """
    Calculate the straight-line distance between two points (in kilometers)
    Uses Haversine formula to calculate the shortest distance between two points on Earth's surface
    """
    # Convert decimal degrees to radians
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))

    # Earth's radius in kilometers
    r = 6371
    return c * r

def fetch_event_episodes(event_data):
    """
    Fetch all episodes for a given event using the details URL

    Parameters:
    event_data (dict): Event data containing URL information

    Returns:
    list: List of episode IDs for the event
    """
    try:
        details_url = event_data['properties']['url']['details']
        print(f"🔍 Fetching episodes for event {event_data['properties']['eventid']}...")

        response = requests.get(details_url, timeout=30)
        response.raise_for_status()

        event_details = response.json()
        episodes = []

        # Extract episode IDs from the response
        if 'episodelist' in event_details:
            for episode in event_details['episodelist']:
                episodes.append(episode.get('episodeid'))
        else:
            # Fallback: use the current episode ID
            episodes.append(event_data['properties']['episodeid'])

        print(f"✅ Found {len(episodes)} episodes: {episodes}")
        return episodes

    except Exception as e:
        print(f"⚠️  Error fetching episodes: {e}")
        # Fallback: use the current episode ID
        return [event_data['properties']['episodeid']]

def fetch_episode_geometry(event_type, event_id, episode_id):
    """
    Fetch geometry for a specific episode

    Parameters:
    event_type (str): Type of event (TC, FL, etc.)
    event_id (int): Event ID
    episode_id (int): Episode ID

    Returns:
    list: List of Shapely geometry objects
    """
    try:
        geometry_url = f"https://www.gdacs.org/gdacsapi/api/polygons/getgeometry?eventtype={event_type}&eventid={event_id}&episodeid={episode_id}"
        print(f"📡 Fetching geometry for episode {episode_id}...")

        response = requests.get(geometry_url, timeout=30)
        response.raise_for_status()

        geojson_data = response.json()
        geometries = []

        # Handle different GeoJSON structures
        if geojson_data.get('type') == 'FeatureCollection':
            for feature in geojson_data.get('features', []):
                if 'geometry' in feature:
                    geom = shape(feature['geometry'])
                    if geom.is_valid:
                        geometries.append(geom)
                    else:
                        # Try to fix invalid geometry
                        fixed_geom = geom.buffer(0)
                        if fixed_geom.is_valid:
                            geometries.append(fixed_geom)

        elif geojson_data.get('type') == 'Feature':
            if 'geometry' in geojson_data:
                geom = shape(geojson_data['geometry'])
                if geom.is_valid:
                    geometries.append(geom)
                else:
                    fixed_geom = geom.buffer(0)
                    if fixed_geom.is_valid:
                        geometries.append(fixed_geom)

        elif 'type' in geojson_data and geojson_data['type'] in ['Polygon', 'MultiPolygon', 'Point']:
            geom = shape(geojson_data)
            if geom.is_valid:
                geometries.append(geom)
            else:
                fixed_geom = geom.buffer(0)
                if fixed_geom.is_valid:
                    geometries.append(fixed_geom)

        print(f"✅ Retrieved {len(geometries)} geometry objects")
        return geometries

    except Exception as e:
        print(f"⚠️  Error fetching geometry for episode {episode_id}: {e}")
        return []

def create_unified_event_geometry(event_data, buffer_km=0):
    """
    Create a unified geometry for an event by combining all its episodes

    Parameters:
    event_data (dict): Event data from JSON
    buffer_km (float): Buffer distance in kilometers (optional)

    Returns:
    tuple: (unified_geometry, bbox, geojson_dict)
    """
    try:
        event_id = event_data['properties']['eventid']
        event_type = event_data['properties']['eventtype']

        print(f"\n🔄 Processing event {event_id} ({event_type})...")

        # Get all episodes for this event
        episodes = fetch_event_episodes(event_data)

        all_geometries = []

        # Fetch geometry for each episode
        for episode_id in episodes:
            episode_geometries = fetch_episode_geometry(event_type, event_id, episode_id)
            all_geometries.extend(episode_geometries)

            # Add small delay to avoid overwhelming the API
            time.sleep(0.5)

        if not all_geometries:
            print(f"❌ No valid geometries found for event {event_id}")
            return None, None, None

        print(f"🔧 Unifying {len(all_geometries)} geometries...")

        # Union all geometries for this event
        if len(all_geometries) == 1:
            unified_geometry = all_geometries[0]
        else:
            unified_geometry = unary_union(all_geometries)

        # Ensure the geometry is valid
        if not unified_geometry.is_valid:
            print("🔧 Fixing invalid geometry...")
            unified_geometry = unified_geometry.buffer(0)

        # Apply buffer if requested
        if buffer_km > 0:
            print(f"🔧 Applying {buffer_km}km buffer...")
            # Convert km to degrees (rough approximation)
            buffer_degrees = buffer_km / 111.32  # 1 degree ≈ 111.32 km
            unified_geometry = unified_geometry.buffer(buffer_degrees)

        # Get bounding box
        bounds = unified_geometry.bounds
        bbox = [bounds[0], bounds[1], bounds[2], bounds[3]]  # [minx, miny, maxx, maxy]

        # Create GeoJSON representation
        if hasattr(unified_geometry, '__geo_interface__'):
            geojson_dict = unified_geometry.__geo_interface__
        else:
            geojson_dict = None

        print(f"✅ Event {event_id} geometry unified successfully")
        return unified_geometry, bbox, geojson_dict

    except Exception as e:
        print(f"❌ Error creating unified geometry for event {event_data['properties']['eventid']}: {e}")
        return None, None, None

def point_to_geometry_distance(point_lon, point_lat, geometry):
    """
    Calculate the shortest distance from a point to a Shapely geometry

    Parameters:
    point_lon (float): Point longitude
    point_lat (float): Point latitude
    geometry: Shapely geometry object

    Returns:
    float: Distance in kilometers
    """
    try:
        point = Point(point_lon, point_lat)

        # If point is inside the geometry, distance is 0
        if geometry.contains(point):
            return 0.0

        # Calculate distance to geometry boundary
        distance_degrees = point.distance(geometry)

        # Convert degrees to kilometers (rough approximation)
        distance_km = distance_degrees * 111.32  # 1 degree ≈ 111.32 km

        return distance_km

    except Exception as e:
        print(f"⚠️  Error calculating distance: {e}")
        return float('inf')

def analyze_disaster_proximity_enhanced(csv_file_path, json_file_path, max_distance_km, buffer_km=0, cache_geometries=True):
    """
    Enhanced analysis function using precise geometries instead of bounding boxes

    Parameters:
    csv_file_path (str): Path to CSV file
    json_file_path (str): Path to JSON file
    max_distance_km (float): Maximum search distance (kilometers)
    buffer_km (float): Buffer distance to add to disaster geometries (kilometers)
    cache_geometries (bool): Whether to cache geometries to avoid re-downloading

    Returns:
    tuple: (matches_list, geometry_cache)
    """

    print(f"🔍 Starting enhanced disaster location analysis...")
    print(f"📊 Maximum search distance: {max_distance_km} km")
    print(f"🛡️  Geometry buffer: {buffer_km} km")
    print("🎯 Using precise polygon geometries instead of bounding boxes\n")

    # Read CSV file
    try:
        df_csv = pd.read_csv(csv_file_path)
        print(f"✅ Successfully loaded CSV file with {len(df_csv)} client records")

        # Check required columns
        required_columns = ['id', 'name', 'address', 'country', 'type', 'latitude', 'longitude']
        missing_columns = [col for col in required_columns if col not in df_csv.columns]
        if missing_columns:
            print(f"⚠️  Warning: CSV file missing columns: {missing_columns}")
            print("Available columns:", list(df_csv.columns))

    except Exception as e:
        print(f"❌ Failed to read CSV file: {e}")
        return [], {}

    # Read JSON file
    try:
        with open(json_file_path, 'r', encoding='utf-8') as f:
            json_data = json.load(f)

        features = json_data.get('features', [])
        print(f"✅ Successfully loaded JSON file with {len(features)} disaster events\n")

    except Exception as e:
        print(f"❌ Failed to read JSON file: {e}")
        return [], {}

    # Process each disaster event to create unified geometries
    geometry_cache = {}
    print("🔄 Creating unified geometries for disaster events...")
    print("=" * 60)

    for i, feature in enumerate(features):
        event_id = feature['properties']['eventid']

        if event_id not in geometry_cache:
            print(f"\n📍 Processing event {i+1}/{len(features)}: {event_id}")

            unified_geometry, bbox, geojson_dict = create_unified_event_geometry(feature, buffer_km)

            if unified_geometry is not None:
                geometry_cache[event_id] = {
                    'geometry': unified_geometry,
                    'bbox': bbox,
                    'geojson': geojson_dict,
                    'properties': feature['properties']
                }
                print(f"✅ Event {event_id} processed successfully")
            else:
                print(f"❌ Failed to process event {event_id}")
        else:
            print(f"📋 Event {event_id} already cached")

    print(f"\n🎯 Successfully processed {len(geometry_cache)} unique events")
    print("=" * 60)

    # Analyze matches using precise geometries
    matches = []

    for idx, client in df_csv.iterrows():
        try:
            client_lat = float(client.get('latitude', 0))
            client_lon = float(client.get('longitude', 0))

            # Skip invalid coordinates
            if client_lat == 0 and client_lon == 0:
                continue

            for event_id, event_cache in geometry_cache.items():
                geometry = event_cache['geometry']
                properties = event_cache['properties']

                # Calculate precise distance to geometry
                distance = point_to_geometry_distance(client_lon, client_lat, geometry)

                # If within specified distance
                if distance <= max_distance_km:
                    match_info = {
                        # Client information
                        "client_info": {
                            "id": str(client.get('id', '')),
                            "name": str(client.get('name', '')),
                            "address": str(client.get('address', '')),
                            "country": str(client.get('country', '')),
                            "type": str(client.get('type', '')),
                            "latitude": float(client_lat),
                            "longitude": float(client_lon),
                            "distance": f"Distance: {round(distance, 1)}km from disaster"
                        },

                        # Disaster information (enhanced)
                        "disaster_info": {
                            "distance_km": round(distance, 2),
                            "distance_calculation": "precise_geometry",
                            "event_type": properties.get('eventtype', ''),
                            "event_name": properties.get('name', ''),
                            "description": properties.get('description', ''),
                            "country": properties.get('country', ''),
                            "alert_level": properties.get('alertlevel', ''),
                            "from_date": properties.get('fromdate', ''),
                            "to_date": properties.get('todate', ''),
                            "severity": properties.get('severitydata', {}).get('severitytext', ''),
                            "unified_bbox": event_cache['bbox'],
                            "full_properties": properties
                        },

                        # Enhanced analysis metadata
                        "analysis_metadata": {
                            "method": "enhanced_geometry_analysis",
                            "search_distance_km": max_distance_km,
                            "buffer_applied_km": buffer_km,
                            "coordinates": {
                                "client_lat": float(client_lat),
                                "client_lon": float(client_lon),
                                "unified_bbox": event_cache['bbox']
                            },
                            "geometry_available": True
                        },

                        # Geometry data (optional, for advanced users)
                        "geometry_data": {
                            "geojson": event_cache.get('geojson'),
                            "bbox": event_cache['bbox']
                        }
                    }
                    matches.append(match_info)

        except (ValueError, TypeError) as e:
            print(f"⚠️  Error processing client {client.get('id', idx)}: {e}")
            continue

    print(f"\n🎯 Found {len(matches)} matching items using precise geometries")
    return matches, geometry_cache

def save_enhanced_results(results, geometry_cache, output_file='enhanced_disaster_analysis_results.json'):
    """
    Save enhanced results including geometry information
    """
    if results:
        # Create enhanced summary statistics
        summary = {
            "analysis_summary": {
                "analysis_method": "enhanced_geometry_analysis",
                "total_matches": len(results),
                "unique_clients": len(set([r['client_info']['id'] for r in results])),
                "unique_events": len(geometry_cache),
                "disaster_types": {},
                "alert_levels": {},
                "countries_affected": {},
                "distance_stats": {
                    "avg_distance": round(sum([r['disaster_info']['distance_km'] for r in results]) / len(results), 2),
                    "max_distance": max([r['disaster_info']['distance_km'] for r in results]),
                    "min_distance": min([r['disaster_info']['distance_km'] for r in results])
                }
            },
            "geometry_summary": {
                "total_events_processed": len(geometry_cache),
                "geometry_types": {},
                "bbox_coverage": []
            },
            "matches": results
        }

        # Calculate statistics
        for result in results:
            disaster_type = result['disaster_info']['event_type']
            alert_level = result['disaster_info']['alert_level']
            country = result['client_info']['country']

            summary["analysis_summary"]["disaster_types"][disaster_type] = summary["analysis_summary"]["disaster_types"].get(disaster_type, 0) + 1
            summary["analysis_summary"]["alert_levels"][alert_level] = summary["analysis_summary"]["alert_levels"].get(alert_level, 0) + 1
            summary["analysis_summary"]["countries_affected"][country] = summary["analysis_summary"]["countries_affected"].get(country, 0) + 1

        # Add geometry statistics
        for event_id, cache_data in geometry_cache.items():
            if cache_data['geometry']:
                geom_type = cache_data['geometry'].geom_type
                summary["geometry_summary"]["geometry_types"][geom_type] = summary["geometry_summary"]["geometry_types"].get(geom_type, 0) + 1
                summary["geometry_summary"]["bbox_coverage"].append(cache_data['bbox'])

        # Save to JSON file
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(summary, f, indent=2, ensure_ascii=False)

        print(f"💾 Enhanced results saved to: {output_file}")
        return summary
    else:
        print("❌ No results to save")
        return None

def save_results_to_excel(results, geometry_cache, output_file='enhanced_disaster_analysis_results.xlsx'):
    """
    Save enhanced results to Excel file with multiple sheets

    Parameters:
    results (list): List of match results
    geometry_cache (dict): Geometry cache data
    output_file (str): Output Excel file path

    Returns:
    str: Output file path if successful, None otherwise
    """
    try:
        if not results:
            print("❌ No results to save to Excel")
            return None

        print(f"📊 Creating Excel file: {output_file}")

        # Create Excel writer object
        with pd.ExcelWriter(output_file, engine='openpyxl') as writer:

            # Sheet 1: Main Results - Detailed matches
            print("📝 Creating 'Detailed_Matches' sheet...")
            detailed_data = []

            for result in results:
                client_info = result['client_info']
                disaster_info = result['disaster_info']
                analysis_meta = result['analysis_metadata']

                # Get full disaster properties from the original JSON
                full_props = disaster_info.get('full_properties', {})

                row = {
                    # === DISASTER/EVENT INFORMATION (place at the front) ===
                    # Basic event information
                    'Event_ID': full_props.get('eventid', ''),
                    'Episode_ID': full_props.get('episodeid', ''),
                    'Event_Type': full_props.get('eventtype', ''),
                    'Event_Name': full_props.get('eventname', ''),
                    'Event_Full_Name': full_props.get('name', ''),
                    'Event_Description': full_props.get('description', ''),
                    'HTML_Description': full_props.get('htmldescription', ''),

                    # Time information
                    'From_Date': full_props.get('fromdate', ''),
                    'To_Date': full_props.get('todate', ''),
                    'Date_Modified': full_props.get('datemodified', ''),

                    # Geographic information
                    'Disaster_Country': full_props.get('country', ''),
                    'ISO3_Code': full_props.get('iso3', ''),
                    'Country_On_Land': full_props.get('countryonland', ''),

                    # Alert information
                    'Alert_Level': full_props.get('alertlevel', ''),
                    'Alert_Score': full_props.get('alertscore', ''),
                    'Episode_Alert_Level': full_props.get('episodealertlevel', ''),
                    'Episode_Alert_Score': full_props.get('episodealertscore', ''),

                    # Severity information
                    'Severity_Value': full_props.get('severitydata', {}).get('severity', ''),
                    'Severity_Text': full_props.get('severitydata', {}).get('severitytext', ''),
                    'Severity_Unit': full_props.get('severitydata', {}).get('severityunit', ''),

                    # Status information
                    'Is_Temporary': full_props.get('istemporary', ''),
                    'Is_Current': full_props.get('iscurrent', ''),

                    # Data source
                    'Data_Source': full_props.get('source', ''),
                    'Source_ID': full_props.get('sourceid', ''),
                    'GLIDE_Number': full_props.get('glide', ''),

                    # URL information
                    'Report_URL': full_props.get('url', {}).get('report', ''),
                    'Details_URL': full_props.get('url', {}).get('details', ''),
                    'Geometry_URL': full_props.get('url', {}).get('geometry', ''),

                    # Icon information
                    'Icon_URL': full_props.get('icon', ''),
                    'Overall_Icon_URL': full_props.get('iconoverall', ''),

                    # Geometry classification
                    'Polygon_Label': full_props.get('polygonlabel', ''),
                    'Geometry_Class': full_props.get('Class', ''),

                    # Affected countries (if multiple)
                    'Affected_Countries_Count': len(full_props.get('affectedcountries', [])),
                    'Affected_Countries_List': ', '.join([country.get('countryname', '') for country in full_props.get('affectedcountries', [])]),
                    'Affected_ISO2_Codes': ', '.join([country.get('iso2', '') for country in full_props.get('affectedcountries', [])]),
                    'Affected_ISO3_Codes': ', '.join([country.get('iso3', '') for country in full_props.get('affectedcountries', [])]),

                    # Unified bounding box
                    'Unified_Bbox_MinLon': disaster_info.get('unified_bbox', [None, None, None, None])[0],
                    'Unified_Bbox_MinLat': disaster_info.get('unified_bbox', [None, None, None, None])[1],
                    'Unified_Bbox_MaxLon': disaster_info.get('unified_bbox', [None, None, None, None])[2],
                    'Unified_Bbox_MaxLat': disaster_info.get('unified_bbox', [None, None, None, None])[3],

                    # === Distance calculation results ===
                    'Distance_KM': disaster_info.get('distance_km', ''),
                    'Distance_Calculation_Method': disaster_info.get('distance_calculation', ''),

                    # === Analysis parameters ===
                    'Search_Distance_KM': analysis_meta.get('search_distance_km', ''),
                    'Buffer_Applied_KM': analysis_meta.get('buffer_applied_km', ''),
                    'Analysis_Method': analysis_meta.get('method', ''),

                    # === CLIENT INFORMATION (place at the end) ===
                    'Client_ID': client_info.get('id', ''),
                    'Client_Name': client_info.get('name', ''),
                    'Client_Address': client_info.get('address', ''),
                    'Client_Country': client_info.get('country', ''),
                    'Client_Type': client_info.get('type', ''),
                    'Client_Latitude': client_info.get('latitude', ''),
                    'Client_Longitude': client_info.get('longitude', ''),
                    'Client_Distance_Summary': client_info.get('distance', ''),
                }
                detailed_data.append(row)

            df_detailed = pd.DataFrame(detailed_data)
            df_detailed.to_excel(writer, sheet_name='Detailed_Matches', index=False)

            # Sheet 2: Summary Statistics
            print("📊 Creating 'Summary_Statistics' sheet...")
            summary_data = []

            # Basic statistics
            total_matches = len(results)
            unique_clients = len(set([r['client_info']['id'] for r in results]))
            unique_events = len(geometry_cache)

            if results:
                distances = [r['disaster_info']['distance_km'] for r in results]
                avg_distance = round(sum(distances) / len(distances), 2)
                max_distance = max(distances)
                min_distance = min(distances)
            else:
                avg_distance = max_distance = min_distance = 0

            summary_stats = [
                ['Metric', 'Value'],
                ['Analysis Method', 'Enhanced Geometry Analysis'],
                ['Analysis Date', datetime.now().strftime('%Y-%m-%d %H:%M:%S')],
                ['Total Matches Found', total_matches],
                ['Unique Clients Affected', unique_clients],
                ['Unique Disaster Events', unique_events],
                ['Average Distance (km)', avg_distance],
                ['Maximum Distance (km)', max_distance],
                ['Minimum Distance (km)', min_distance],
            ]

            df_summary = pd.DataFrame(summary_stats[1:], columns=summary_stats[0])
            df_summary.to_excel(writer, sheet_name='Summary_Statistics', index=False)

            # Sheet 3: Disaster Types Analysis
            print("📈 Creating 'Disaster_Types' sheet...")
            disaster_types = {}
            alert_levels = {}
            countries_affected = {}

            for result in results:
                dtype = result['disaster_info']['event_type']
                alert = result['disaster_info']['alert_level']
                country = result['client_info']['country']

                disaster_types[dtype] = disaster_types.get(dtype, 0) + 1
                alert_levels[alert] = alert_levels.get(alert, 0) + 1
                countries_affected[country] = countries_affected.get(country, 0) + 1

            # Create disaster types dataframe
            disaster_types_data = [['Disaster_Type', 'Count', 'Percentage']]
            for dtype, count in disaster_types.items():
                percentage = round((count / total_matches) * 100, 1) if total_matches > 0 else 0
                disaster_types_data.append([dtype, count, f"{percentage}%"])

            df_disaster_types = pd.DataFrame(disaster_types_data[1:], columns=disaster_types_data[0])
            df_disaster_types.to_excel(writer, sheet_name='Disaster_Types', index=False)

            # Sheet 4: Alert Levels Analysis
            print("🚨 Creating 'Alert_Levels' sheet...")
            alert_levels_data = [['Alert_Level', 'Count', 'Percentage']]
            for alert, count in alert_levels.items():
                percentage = round((count / total_matches) * 100, 1) if total_matches > 0 else 0
                alert_levels_data.append([alert, count, f"{percentage}%"])

            df_alert_levels = pd.DataFrame(alert_levels_data[1:], columns=alert_levels_data[0])
            df_alert_levels.to_excel(writer, sheet_name='Alert_Levels', index=False)

            # Sheet 5: Countries Analysis
            print("🌍 Creating 'Countries_Affected' sheet...")
            countries_data = [['Country', 'Affected_Clients', 'Percentage']]
            for country, count in countries_affected.items():
                percentage = round((count / total_matches) * 100, 1) if total_matches > 0 else 0
                countries_data.append([country, count, f"{percentage}%"])

            df_countries = pd.DataFrame(countries_data[1:], columns=countries_data[0])
            df_countries.to_excel(writer, sheet_name='Countries_Affected', index=False)

            # Sheet 6: Distance Analysis
            print("📏 Creating 'Distance_Analysis' sheet...")
            if results:
                # Create distance bins
                distances = [r['disaster_info']['distance_km'] for r in results]
                distance_ranges = ['0-10km', '10-25km', '25-50km', '50-100km', '100-200km', '200km+']
                distance_counts = [0, 0, 0, 0, 0, 0]

                for dist in distances:
                    if dist <= 10:
                        distance_counts[0] += 1
                    elif dist <= 25:
                        distance_counts[1] += 1
                    elif dist <= 50:
                        distance_counts[2] += 1
                    elif dist <= 100:
                        distance_counts[3] += 1
                    elif dist <= 200:
                        distance_counts[4] += 1
                    else:
                        distance_counts[5] += 1

                distance_analysis_data = []
                for i, (range_name, count) in enumerate(zip(distance_ranges, distance_counts)):
                    percentage = round((count / total_matches) * 100, 1) if total_matches > 0 else 0
                    distance_analysis_data.append([range_name, count, f"{percentage}%"])

                df_distance = pd.DataFrame(distance_analysis_data, columns=['Distance_Range', 'Count', 'Percentage'])
                df_distance.to_excel(writer, sheet_name='Distance_Analysis', index=False)

            # Sheet 7: All Disaster Events (complete disaster event data)
            print("🌪️  Creating 'All_Disaster_Events' sheet...")
            all_events_data = []

            for event_id, cache_data in geometry_cache.items():
                if cache_data.get('properties'):
                    props = cache_data['properties']
                    bbox = cache_data.get('bbox', [None, None, None, None])
                    geom_type = cache_data['geometry'].geom_type if cache_data.get('geometry') else 'Unknown'

                    row = {
                        # Basic event information
                        'Event_ID': props.get('eventid', ''),
                        'Episode_ID': props.get('episodeid', ''),
                        'Event_Type': props.get('eventtype', ''),
                        'Event_Name': props.get('eventname', ''),
                        'Full_Name': props.get('name', ''),
                        'Description': props.get('description', ''),
                        'HTML_Description': props.get('htmldescription', ''),

                        # Time information
                        'From_Date': props.get('fromdate', ''),
                        'To_Date': props.get('todate', ''),
                        'Date_Modified': props.get('datemodified', ''),

                        # Geographic information
                        'Country': props.get('country', ''),
                        'ISO3_Code': props.get('iso3', ''),
                        'Country_On_Land': props.get('countryonland', ''),

                        # Alert information
                        'Alert_Level': props.get('alertlevel', ''),
                        'Alert_Score': props.get('alertscore', ''),
                        'Episode_Alert_Level': props.get('episodealertlevel', ''),
                        'Episode_Alert_Score': props.get('episodealertscore', ''),

                        # Severity information
                        'Severity_Value': props.get('severitydata', {}).get('severity', ''),
                        'Severity_Text': props.get('severitydata', {}).get('severitytext', ''),
                        'Severity_Unit': props.get('severitydata', {}).get('severityunit', ''),

                        # Status information
                        'Is_Temporary': props.get('istemporary', ''),
                        'Is_Current': props.get('iscurrent', ''),

                        # Data source
                        'Data_Source': props.get('source', ''),
                        'Source_ID': props.get('sourceid', ''),
                        'GLIDE_Number': props.get('glide', ''),

                        # URL information
                        'Report_URL': props.get('url', {}).get('report', ''),
                        'Details_URL': props.get('url', {}).get('details', ''),
                        'Geometry_URL': props.get('url', {}).get('geometry', ''),

                        # Icon information
                        'Icon_URL': props.get('icon', ''),
                        'Overall_Icon_URL': props.get('iconoverall', ''),

                        # Geometry classification
                        'Polygon_Label': props.get('polygonlabel', ''),
                        'Geometry_Class': props.get('Class', ''),
                        'Processed_Geometry_Type': geom_type,

                        # Affected countries
                        'Affected_Countries_Count': len(props.get('affectedcountries', [])),
                        'Affected_Countries_List': ', '.join([country.get('countryname', '') for country in props.get('affectedcountries', [])]),
                        'Affected_ISO2_Codes': ', '.join([country.get('iso2', '') for country in props.get('affectedcountries', [])]),
                        'Affected_ISO3_Codes': ', '.join([country.get('iso3', '') for country in props.get('affectedcountries', [])]),

                        # Unified bounding box
                        'Unified_Bbox_MinLon': bbox[0],
                        'Unified_Bbox_MinLat': bbox[1],
                        'Unified_Bbox_MaxLon': bbox[2],
                        'Unified_Bbox_MaxLat': bbox[3],

                        # Whether there are matching clients
                        'Has_Affected_Clients': any(result['disaster_info']['event_type'] == props.get('eventtype', '') and
                                                  str(result['disaster_info'].get('full_properties', {}).get('eventid', '')) == str(props.get('eventid', ''))
                                                  for result in results),
                        'Affected_Clients_Count': sum(1 for result in results
                                                    if str(result['disaster_info'].get('full_properties', {}).get('eventid', '')) == str(props.get('eventid', '')))
                    }
                    all_events_data.append(row)

            if all_events_data:
                df_all_events = pd.DataFrame(all_events_data)
                df_all_events.to_excel(writer, sheet_name='All_Disaster_Events', index=False)

            # Sheet 8: Geometry Information (simplified version, detailed data already above)
            print("🗺️  Creating 'Geometry_Summary' sheet...")
            geometry_data = []

            for event_id, cache_data in geometry_cache.items():
                if cache_data.get('properties'):
                    props = cache_data['properties']
                    bbox = cache_data.get('bbox', [None, None, None, None])
                    geom_type = cache_data['geometry'].geom_type if cache_data.get('geometry') else 'Unknown'

                    # Calculate geometry statistics
                    geometry_area = 0
                    geometry_perimeter = 0
                    if cache_data.get('geometry'):
                        try:
                            # Approximate area calculation (square degrees)
                            geometry_area = cache_data['geometry'].area
                            # Approximate perimeter calculation (degrees)
                            geometry_perimeter = cache_data['geometry'].length
                        except:
                            pass

                    row = {
                        'Event_ID': event_id,
                        'Event_Type': props.get('eventtype', ''),
                        'Event_Name': props.get('name', ''),
                        'Alert_Level': props.get('alertlevel', ''),
                        'Country': props.get('country', ''),
                        'From_Date': props.get('fromdate', ''),
                        'To_Date': props.get('todate', ''),
                        'Geometry_Type': geom_type,
                        'Geometry_Area_Deg2': round(geometry_area, 6) if geometry_area > 0 else '',
                        'Geometry_Perimeter_Deg': round(geometry_perimeter, 6) if geometry_perimeter > 0 else '',
                        'Bbox_MinLon': bbox[0],
                        'Bbox_MinLat': bbox[1],
                        'Bbox_MaxLon': bbox[2],
                        'Bbox_MaxLat': bbox[3],
                        'Bbox_Width_Deg': round(bbox[2] - bbox[0], 6) if bbox[0] is not None and bbox[2] is not None else '',
                        'Bbox_Height_Deg': round(bbox[3] - bbox[1], 6) if bbox[1] is not None and bbox[3] is not None else '',
                        'Has_Affected_Clients': any(str(result['disaster_info'].get('full_properties', {}).get('eventid', '')) == str(event_id) for result in results),
                        'Affected_Clients_Count': sum(1 for result in results if str(result['disaster_info'].get('full_properties', {}).get('eventid', '')) == str(event_id))
                    }
                    geometry_data.append(row)

            if geometry_data:
                df_geometry = pd.DataFrame(geometry_data)
                df_geometry.to_excel(writer, sheet_name='Geometry_Summary', index=False)

        print(f"✅ Excel file successfully created: {output_file}")
        print(f"📊 Created {8 if geometry_data else 7} sheets with comprehensive analysis")
        return output_file

    except Exception as e:
        print(f"❌ Error creating Excel file: {e}")
        return None

def export_geometries_geojson(geometry_cache, output_file='disaster_geometries.geojson'):
    """
    Export unified geometries as a GeoJSON file
    """
    try:
        features = []

        for event_id, cache_data in geometry_cache.items():
            if cache_data.get('geojson'):
                feature = {
                    "type": "Feature",
                    "properties": {
                        "event_id": event_id,
                        "event_type": cache_data['properties'].get('eventtype', ''),
                        "event_name": cache_data['properties'].get('name', ''),
                        "alert_level": cache_data['properties'].get('alertlevel', ''),
                        "country": cache_data['properties'].get('country', ''),
                        "from_date": cache_data['properties'].get('fromdate', ''),
                        "to_date": cache_data['properties'].get('todate', '')
                    },
                    "geometry": cache_data['geojson']
                }
                features.append(feature)

        geojson_output = {
            "type": "FeatureCollection",
            "features": features
        }

        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(geojson_output, f, indent=2, ensure_ascii=False)

        print(f"🗺️  Geometries exported to: {output_file}")
        return True

    except Exception as e:
        print(f"❌ Error exporting geometries: {e}")
        return False

def interactive_enhanced_setup():
    """
    Interactive setup for enhanced analysis
    """
    print("🌍 Enhanced Disaster Location Analysis Tool")
    print("=" * 60)
    print("🎯 This version uses precise polygon geometries instead of bounding boxes")
    print("📁 File Setup")
    print("=" * 60)

    # Check existing files
    content_files = [f for f in os.listdir('/content') if f.endswith(('.csv', '.json', '.txt'))]

    if content_files:
        print("📂 Found the following files in /content directory:")
        for i, file in enumerate(content_files, 1):
            print(f"   {i}. {file}")
        print()

    # CSV file setup
    print("🗂️ CSV File Setup:")
    csv_option = input("Choose option [1]Upload new file [2]Use existing file [3]Manual path: ").strip()

    if csv_option == "1":
        print("Please upload your CSV file...")
        try:
            from google.colab import files
            uploaded_csv = files.upload()
            csv_file_path = f"/content/{list(uploaded_csv.keys())[0]}"
        except ImportError:
            csv_file_path = input("Google Colab not detected. Enter CSV file path: ").strip()
    elif csv_option == "2" and content_files:
        print("Select CSV file:")
        csv_files = [f for f in content_files if f.endswith('.csv')]
        for i, file in enumerate(csv_files, 1):
            print(f"   {i}. {file}")
        csv_choice = int(input("Enter file number: ")) - 1
        csv_file_path = f"/content/{csv_files[csv_choice]}"
    else:
        csv_file_path = input("Enter CSV file full path: ").strip()

    # JSON file setup
    print("\n🗂️ JSON Disaster Data File Setup:")
    json_option = input("Choose option [1]Upload new file [2]Use existing file [3]Manual path: ").strip()

    if json_option == "1":
        print("Please upload your JSON file...")
        try:
            from google.colab import files
            uploaded_json = files.upload()
            json_file_path = f"/content/{list(uploaded_json.keys())[0]}"
        except ImportError:
            json_file_path = input("Google Colab not detected. Enter JSON file path: ").strip()
    elif json_option == "2" and content_files:
        print("Select JSON file:")
        json_files = [f for f in content_files if f.endswith(('.json', '.txt'))]
        for i, file in enumerate(json_files, 1):
            print(f"   {i}. {file}")
        json_choice = int(input("Enter file number: ")) - 1
        json_file_path = f"/content/{json_files[json_choice]}"
    else:
        json_file_path = input("Enter JSON file full path: ").strip()

    print(f"\n✅ CSV file path: {csv_file_path}")
    print(f"✅ JSON file path: {json_file_path}")

    return csv_file_path, json_file_path

def main_enhanced():
    """
    Main enhanced function with precise geometry analysis
    """
    try:
        # Interactive file setup
        csv_file_path, json_file_path = interactive_enhanced_setup()

        # Get search distance
        print("\n🎯 Search Distance Configuration")
        print("=" * 40)
        print("💡 Recommended distance ranges:")
        print("   • 10-50km: Close proximity analysis")
        print("   • 50-200km: Medium range analysis")
        print("   • 200km+: Wide area analysis")

        while True:
            try:
                distance_input = input("\nEnter maximum search distance (km): ").strip()
                max_distance_km = float(distance_input)
                if max_distance_km > 0:
                    break
                else:
                    print("❌ Distance must be positive")
            except ValueError:
                print("❌ Please enter a valid number")

        # Get buffer distance
        print("\n🛡️  Buffer Configuration (Optional)")
        print("=" * 40)
        print("💡 Buffer adds safety margin around disaster areas:")
        print("   • 0km: No buffer (exact geometry)")
        print("   • 5-20km: Small safety margin")
        print("   • 50km+: Large safety zone")

        while True:
            try:
                buffer_input = input("Enter buffer distance (km) [0 for no buffer]: ").strip()
                if not buffer_input:
                    buffer_km = 0
                    break
                buffer_km = float(buffer_input)
                if buffer_km >= 0:
                    break
                else:
                    print("❌ Buffer must be non-negative")
            except ValueError:
                print("❌ Please enter a valid number")

        print(f"\n🚀 Starting enhanced analysis...")
        print("=" * 60)

        # Execute enhanced analysis
        results, geometry_cache = analyze_disaster_proximity_enhanced(
            csv_file_path, json_file_path, max_distance_km, buffer_km
        )

        if results:
            # Display summary
            print("\n📋 Enhanced Analysis Summary")
            print("=" * 40)
            print(f"🎯 Total matches found: {len(results)}")
            print(f"👥 Unique clients affected: {len(set([r['client_info']['id'] for r in results]))}")
            print(f"🌪️  Unique events processed: {len(geometry_cache)}")

            # Show disaster types
            disaster_types = {}
            for result in results:
                dtype = result['disaster_info']['event_type']
                disaster_types[dtype] = disaster_types.get(dtype, 0) + 1

            print(f"\n🌪️ Disaster types found:")
            for dtype, count in disaster_types.items():
                print(f"   • {dtype}: {count}")

            # Save options
            print("\n💾 Save Results")
            print("=" * 30)
            save_option = input("Save results to files? [Y/n]: ").lower().strip()

            if save_option in ['', 'y', 'yes']:
                # JSON output
                default_json_name = f"enhanced_disaster_analysis_{max_distance_km}km_buffer{buffer_km}km.json"
                json_filename = input(f"JSON filename (default: {default_json_name}): ").strip()
                if not json_filename:
                    json_filename = default_json_name

                summary = save_enhanced_results(results, geometry_cache, json_filename)

                # Excel output
                excel_option = input("Also save as Excel file? [Y/n]: ").lower().strip()
                if excel_option in ['', 'y', 'yes']:
                    default_excel_name = f"enhanced_disaster_analysis_{max_distance_km}km_buffer{buffer_km}km.xlsx"
                    excel_filename = input(f"Excel filename (default: {default_excel_name}): ").strip()
                    if not excel_filename:
                        excel_filename = default_excel_name

                    excel_path = save_results_to_excel(results, geometry_cache, excel_filename)

                # Option to export geometries
                export_option = input("Export unified geometries as GeoJSON? [y/N]: ").lower().strip()
                if export_option in ['y', 'yes']:
                    geojson_filename = f"unified_geometries_{max_distance_km}km.geojson"
                    export_geometries_geojson(geometry_cache, geojson_filename)

                # Download option for Google Colab
                try:
                    from google.colab import files
                    download_option = input("Download files to local machine? [y/N]: ").lower().strip()
                    if download_option in ['y', 'yes']:
                        files.download(json_filename)
                        if excel_option in ['', 'y', 'yes'] and excel_path:
                            files.download(excel_filename)
                        if export_option in ['y', 'yes']:
                            files.download(geojson_filename)
                        print("📥 File download completed!")
                except ImportError:
                    print("💡 Files saved locally. Google Colab download not available.")
                except Exception as e:
                    print(f"⚠️ Download failed: {e}")

            print("\n🎉 Enhanced analysis completed successfully!")
            print("💡 This analysis used precise polygon geometries for accurate distance calculations")
            return results, geometry_cache

        else:
            print("\n❌ No matches found.")
            print("💡 Suggestions:")
            print("   • Increase search distance")
            print("   • Add buffer distance")
            print("   • Check coordinate data accuracy")
            print("   • Verify disaster data format")
            return [], {}

    except KeyboardInterrupt:
        print("\n\n⏹️ Analysis interrupted by user")
        return [], {}
    except Exception as e:
        print(f"\n❌ Error during execution: {e}")
        print("💡 Please check file paths and internet connection")
        return [], {}

def quick_enhanced_analysis(csv_path=None, json_path=None):
    """
    Quick enhanced analysis function
    """
    # Use default paths or provided paths
    if csv_path is None:
        csv_path = "/content/merged_full_dataset_with_coordinates.csv"
    if json_path is None:
        json_path = "/content/merged_geojson.json"

    print(f"🚀 Quick Enhanced Analysis Mode")
    print(f"📁 CSV: {csv_path}")
    print(f"📁 JSON: {json_path}")
    print("=" * 50)

    # Get parameters
    while True:
        try:
            distance_input = input("Enter search distance (km): ").strip()
            distance = float(distance_input)
            if distance > 0:
                break
            else:
                print("❌ Distance must be positive")
        except ValueError:
            print("❌ Please enter a valid number")

    while True:
        try:
            buffer_input = input("Enter buffer distance (km) [0]: ").strip()
            if not buffer_input:
                buffer = 0
                break
            buffer = float(buffer_input)
            if buffer >= 0:
                break
            else:
                print("❌ Buffer must be non-negative")
        except ValueError:
            print("❌ Please enter a valid number")

    results, geometry_cache = analyze_disaster_proximity_enhanced(csv_path, json_path, distance, buffer)

    if results:
        print(f"\n📊 Found {len(results)} matches")

        # Save results
        save_option = input("Save to files? [Y/n]: ").lower().strip()
        if save_option in ['', 'y', 'yes']:
            # JSON output
            json_output_file = f"enhanced_disaster_analysis_{distance}km_buffer{buffer}km.json"
            save_enhanced_results(results, geometry_cache, json_output_file)

            # Excel output
            excel_option = input("Also save as Excel? [Y/n]: ").lower().strip()
            if excel_option in ['', 'y', 'yes']:
                excel_output_file = f"enhanced_disaster_analysis_{distance}km_buffer{buffer}km.xlsx"
                save_results_to_excel(results, geometry_cache, excel_output_file)

        return results, geometry_cache
    else:
        print("❌ No matches found")
        return [], {}

# Execute in Google Colab
if __name__ == "__main__":
    print("🌍 Enhanced Disaster Location Analysis Tool - Google Colab Edition")
    print("=" * 70)
    print("🎯 This version uses precise polygon geometries instead of simple bounding boxes")
    print("📋 Execution Options:")
    print("   1. 🎮 Interactive Enhanced Analysis (Recommended)")
    print("   2. ⚡ Quick Enhanced Analysis")
    print("   3. 📖 View Instructions")
    print("=" * 70)

    try:
        mode = input("Select execution mode [1/2/3]: ").strip()

        if mode == "1":
            print("\n🎮 Starting Interactive Enhanced Analysis...")
            results, geometry_cache = main_enhanced()
        elif mode == "2":
            print("\n⚡ Quick Enhanced Analysis Mode")
            print("💡 Using default file paths, use interactive mode to modify")
            results, geometry_cache = quick_enhanced_analysis()
        else:
            print("\n📖 Instructions:")
            print("=" * 40)
            print("🔧 Manual Function Calls:")
            print("   • main_enhanced() - Full interactive enhanced analysis")
            print("   • quick_enhanced_analysis() - Quick enhanced analysis")
            print("   • analyze_disaster_proximity_enhanced(csv_path, json_path, distance, buffer) - Core enhanced analysis")
            print("\n📁 File Requirements:")
            print("   • CSV: id, name, address, country, type, latitude, longitude")
            print("   • JSON: GeoJSON format with disaster features and URL information for geometry fetching")
            print("\n🆕 Enhanced Features:")
            print("   • Fetches actual polygon geometries from GDACS API")
            print("   • Unifies multiple episodes into single event geometry")
            print("   • Calculates precise distance to polygon boundaries")
            print("   • Optional buffer zones around disaster areas")
            print("   • Exports unified geometries as GeoJSON")
            print("   • Comprehensive Excel reports with multiple analysis sheets")
            print("\n💡 Example:")
            print("   results, cache = quick_enhanced_analysis('/content/data.csv', '/content/disasters.json')")
            print("\n⚠️  Requirements:")
            print("   • Internet connection (for API calls)")
            print("   • Python packages: shapely, requests, openpyxl")
            print("   • Install with: !pip install shapely requests openpyxl")

    except KeyboardInterrupt:
        print("\n👋 Program terminated")
    except Exception as e:
        print(f"\n❌ Error occurred: {e}")
        print("💡 Please restart or use main_enhanced() function")
        print("💡 Make sure to install required packages: !pip install shapely requests openpyxl")
# Out:
# 🌍 Enhanced Disaster Location Analysis Tool - Google Colab Edition
# ======================================================================
# 🎯 This version uses precise polygon geometries instead of simple bounding boxes
# 📋 Execution Options:
#    1. 🎮 Interactive Enhanced Analysis (Recommended)
#    2. ⚡ Quick Enhanced Analysis
#    3. 📖 View Instructions
# ======================================================================
# Select execution mode [1/2/3]: 1
#
# 🎮 Starting Interactive Enhanced Analysis...
# 🌍 Enhanced Disaster Location Analysis Tool
# ============================================================
# 🎯 This version uses precise polygon geometries instead of bounding boxes
# 📁 File Setup
# ============================================================
# 📂 Found the following files in /content directory:
#    1. merged_full_dataset_with_coordinates.csv
#    2. merged_data.csv
#    3. merged_geojson.json
#
# 🗂️ CSV File Setup:
# Choose option [1]Upload new file [2]Use existing file [3]Manual path: 2
# Select CSV file:
#    1. merged_full_dataset_with_coordinates.csv
#    2. merged_data.csv
# Enter file number: 1
#
# 🗂️ JSON Disaster Data File Setup:
# Choose option [1]Upload new file [2]Use existing file [3]Manual path: 2
# Select JSON file:
#    1. merged_geojson.json
# Enter file number: 1
#
# ✅ CSV file path: /content/merged_full_dataset_with_coordinates.csv
# ✅ JSON file path: /content/merged_geojson.json
#
# 🎯 Search Distance Configuration
# ========================================
# 💡 Recommended distance ranges:
#    • 10-50km: Close proximity analysis
#    • 50-200km: Medium range analysis
#    • 200km+: Wide area analysis
#
# Enter maximum search distance (km): 400
#
# 🛡️  Buffer Configuration (Optional)
# ========================================
# 💡 Buffer adds safety margin around disaster areas:
#    • 0km: No buffer (exact geometry)
#    • 5-20km: Small safety margin
#    • 50km+: Large safety zone
# Enter buffer distance (km) [0 for no buffer]: 10
#
# 🚀 Starting enhanced analysis...
# ============================================================
# 🔍 Starting enhanced disaster location analysis...
# 📊 Maximum search distance: 400.0 km
# 🛡️  Geometry buffer: 10.0 km
# 🎯 Using precise polygon geometries instead of bounding boxes
#
# ✅ Successfully loaded CSV file with 34 client records
# ✅ Successfully loaded JSON file with 306 disaster events
#
# 🔄 Creating unified geometries for disaster events...
# ============================================================
#
# 📍 Processing event 1/306: 1001194
#
# 🔄 Processing event 1001194 (TC)...
# 🔍 Fetching episodes for event 1001194...
# ✅ Found 1 episodes: [17]
# 📡 Fetching geometry for episode 17...
# ✅ Retrieved 50 geometry objects
# 🔧 Unifying 50 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001194 geometry unified successfully
# ✅ Event 1001194 processed successfully
#
# 📍 Processing event 2/306: 1103277
#
# 🔄 Processing event 1103277 (FL)...
# 🔍 Fetching episodes for event 1103277...
# ✅ Found 1 episodes: [32]
# 📡 Fetching geometry for episode 32...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1103277 geometry unified successfully
# ✅ Event 1103277 processed successfully
#
# 📍 Processing event 3/306: 1001183
#
# 🔄 Processing event 1001183 (TC)...
# 🔍 Fetching episodes for event 1001183...
# ✅ Found 1 episodes: [31]
# 📡 Fetching geometry for episode 31...
# ✅ Retrieved 72 geometry objects
# 🔧 Unifying 72 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001183 geometry unified successfully
# ✅ Event 1001183 processed successfully
#
# 📍 Processing event 4/306: 1001181
#
# 🔄 Processing event 1001181 (TC)...
# 🔍 Fetching episodes for event 1001181...
# ✅ Found 1 episodes: [16]
# 📡 Fetching geometry for episode 16...
# ✅ Retrieved 40 geometry objects
# 🔧 Unifying 40 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001181 geometry unified successfully
# ✅ Event 1001181 processed successfully
#
# 📍 Processing event 5/306: 1001166
#
# 🔄 Processing event 1001166 (TC)...
# 🔍 Fetching episodes for event 1001166...
# ✅ Found 1 episodes: [16]
# 📡 Fetching geometry for episode 16...
# ✅ Retrieved 42 geometry objects
# 🔧 Unifying 42 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001166 geometry unified successfully
# ✅ Event 1001166 processed successfully
#
# 📍 Processing event 6/306: 1481374
#
# 🔄 Processing event 1481374 (EQ)...
# 🔍 Fetching episodes for event 1481374...
# ✅ Found 1 episodes: [1638362]
# 📡 Fetching geometry for episode 1638362...
# ✅ Retrieved 12 geometry objects
# 🔧 Unifying 12 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1481374 geometry unified successfully
# ✅ Event 1481374 processed successfully
#
# 📍 Processing event 7/306: 1461014
#
# 🔄 Processing event 1461014 (EQ)...
# 🔍 Fetching episodes for event 1461014...
# ✅ Found 1 episodes: [1613521]
# 📡 Fetching geometry for episode 1613521...
# ✅ Retrieved 13 geometry objects
# 🔧 Unifying 13 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1461014 geometry unified successfully
# ✅ Event 1461014 processed successfully
#
# 📍 Processing event 8/306: 1001124
#
# 🔄 Processing event 1001124 (TC)...
# 🔍 Fetching episodes for event 1001124...
# ✅ Found 1 episodes: [43]
# 📡 Fetching geometry for episode 43...
# ✅ Retrieved 94 geometry objects
# 🔧 Unifying 94 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001124 geometry unified successfully
# ✅ Event 1001124 processed successfully
#
# 📍 Processing event 9/306: 1001125
#
# 🔄 Processing event 1001125 (TC)...
# 🔍 Fetching episodes for event 1001125...
# ✅ Found 1 episodes: [20]
# 📡 Fetching geometry for episode 20...
# ✅ Retrieved 48 geometry objects
# 🔧 Unifying 48 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001125 geometry unified successfully
# ✅ Event 1001125 processed successfully
#
# 📍 Processing event 10/306: 1001118
#
# 🔄 Processing event 1001118 (TC)...
# 🔍 Fetching episodes for event 1001118...
# ✅ Found 1 episodes: [32]
# 📡 Fetching geometry for episode 32...
# ✅ Retrieved 70 geometry objects
# 🔧 Unifying 70 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001118 geometry unified successfully
# ✅ Event 1001118 processed successfully
#
# 📍 Processing event 11/306: 1001115
#
# 🔄 Processing event 1001115 (TC)...
# 🔍 Fetching episodes for event 1001115...
# ✅ Found 1 episodes: [34]
# 📡 Fetching geometry for episode 34...
# ✅ Retrieved 73 geometry objects
# 🔧 Unifying 73 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001115 geometry unified successfully
# ✅ Event 1001115 processed successfully
#
# 📍 Processing event 12/306: 1001105
#
# 🔄 Processing event 1001105 (TC)...
# 🔍 Fetching episodes for event 1001105...
# ✅ Found 1 episodes: [27]
# 📡 Fetching geometry for episode 27...
# ✅ Retrieved 62 geometry objects
# 🔧 Unifying 62 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001105 geometry unified successfully
# ✅ Event 1001105 processed successfully
#
# 📍 Processing event 13/306: 1001093
#
# 🔄 Processing event 1001093 (TC)...
# 🔍 Fetching episodes for event 1001093...
# ✅ Found 1 episodes: [25]
# 📡 Fetching geometry for episode 25...
# ✅ Retrieved 60 geometry objects
# 🔧 Unifying 60 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001093 geometry unified successfully
# ✅ Event 1001093 processed successfully
#
# 📍 Processing event 14/306: 1001090
#
# 🔄 Processing event 1001090 (TC)...
# 🔍 Fetching episodes for event 1001090...
# ✅ Found 1 episodes: [24]
# 📡 Fetching geometry for episode 24...
# ✅ Retrieved 60 geometry objects
# 🔧 Unifying 60 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001090 geometry unified successfully
# ✅ Event 1001090 processed successfully
#
# 📍 Processing event 15/306: 1001072
#
# 🔄 Processing event 1001072 (TC)...
# 🔍 Fetching episodes for event 1001072...
# ✅ Found 1 episodes: [24]
# 📡 Fetching geometry for episode 24...
# ✅ Retrieved 59 geometry objects
# 🔧 Unifying 59 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001072 geometry unified successfully
# ✅ Event 1001072 processed successfully
#
# 📍 Processing event 16/306: 1411622
#
# 🔄 Processing event 1411622 (EQ)...
# 🔍 Fetching episodes for event 1411622...
# ✅ Found 1 episodes: [1548715]
# 📡 Fetching geometry for episode 1548715...
# ✅ Retrieved 13 geometry objects
# 🔧 Unifying 13 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1411622 geometry unified successfully
# ✅ Event 1411622 processed successfully
#
# 📍 Processing event 17/306: 1406601
#
# 🔄 Processing event 1406601 (EQ)...
# 🔍 Fetching episodes for event 1406601...
# ✅ Found 1 episodes: [1543048]
# 📡 Fetching geometry for episode 1543048...
# ✅ Retrieved 11 geometry objects
# 🔧 Unifying 11 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1406601 geometry unified successfully
# ✅ Event 1406601 processed successfully
#
# 📍 Processing event 18/306: 1001018
#
# 🔄 Processing event 1001018 (TC)...
# 🔍 Fetching episodes for event 1001018...
# ✅ Found 1 episodes: [43]
# 📡 Fetching geometry for episode 43...
# ✅ Retrieved 92 geometry objects
# 🔧 Unifying 92 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001018 geometry unified successfully
# ✅ Event 1001018 processed successfully
#
# 📍 Processing event 19/306: 1001002
#
# 🔄 Processing event 1001002 (TC)...
# 🔍 Fetching episodes for event 1001002...
# ✅ Found 1 episodes: [30]
# 📡 Fetching geometry for episode 30...
# ✅ Retrieved 72 geometry objects
# 🔧 Unifying 72 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001002 geometry unified successfully
# ✅ Event 1001002 processed successfully
#
# 📍 Processing event 20/306: 1000999
#
# 🔄 Processing event 1000999 (TC)...
# 🔍 Fetching episodes for event 1000999...
# ✅ Found 1 episodes: [44]
# 📡 Fetching geometry for episode 44...
# ✅ Retrieved 96 geometry objects
# 🔧 Unifying 96 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000999 geometry unified successfully
# ✅ Event 1000999 processed successfully
#
# 📍 Processing event 21/306: 1385761
#
# 🔄 Processing event 1385761 (EQ)...
# 🔍 Fetching episodes for event 1385761...
# ✅ Found 1 episodes: [1518909]
# 📡 Fetching geometry for episode 1518909...
# ✅ Retrieved 12 geometry objects
# 🔧 Unifying 12 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1385761 geometry unified successfully
# ✅ Event 1385761 processed successfully
#
# 📍 Processing event 22/306: 1000985
#
# 🔄 Processing event 1000985 (TC)...
# 🔍 Fetching episodes for event 1000985...
# ✅ Found 1 episodes: [28]
# 📡 Fetching geometry for episode 28...
# ✅ Retrieved 68 geometry objects
# 🔧 Unifying 68 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000985 geometry unified successfully
# ✅ Event 1000985 processed successfully
#
# 📍 Processing event 23/306: 1102095
#
# 🔄 Processing event 1102095 (FL)...
# 🔍 Fetching episodes for event 1102095...
# ✅ Found 1 episodes: [8]
# 📡 Fetching geometry for episode 8...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1102095 geometry unified successfully
# ✅ Event 1102095 processed successfully
#
# 📍 Processing event 24/306: 1000972
#
# 🔄 Processing event 1000972 (TC)...
# 🔍 Fetching episodes for event 1000972...
# ✅ Found 1 episodes: [57]
# 📡 Fetching geometry for episode 57...
# ✅ Retrieved 120 geometry objects
# 🔧 Unifying 120 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000972 geometry unified successfully
# ✅ Event 1000972 processed successfully
#
# 📍 Processing event 25/306: 1000937
#
# 🔄 Processing event 1000937 (TC)...
# 🔍 Fetching episodes for event 1000937...
# ✅ Found 1 episodes: [24]
# 📡 Fetching geometry for episode 24...
# ✅ Retrieved 56 geometry objects
# 🔧 Unifying 56 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000937 geometry unified successfully
# ✅ Event 1000937 processed successfully
#
# 📍 Processing event 26/306: 1338219
#
# 🔄 Processing event 1338219 (EQ)...
# 🔍 Fetching episodes for event 1338219...
# ✅ Found 1 episodes: [1462682]
# 📡 Fetching geometry for episode 1462682...
# ✅ Retrieved 12 geometry objects
# 🔧 Unifying 12 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1338219 geometry unified successfully
# ✅ Event 1338219 processed successfully
#
# 📍 Processing event 27/306: 1000913
#
# 🔄 Processing event 1000913 (TC)...
# 🔍 Fetching episodes for event 1000913...
# ✅ Found 1 episodes: [40]
# 📡 Fetching geometry for episode 40...
# ✅ Retrieved 88 geometry objects
# 🔧 Unifying 88 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000913 geometry unified successfully
# ✅ Event 1000913 processed successfully
#
# 📍 Processing event 28/306: 1101664
#
# 🔄 Processing event 1101664 (FL)...
# 🔍 Fetching episodes for event 1101664...
# ✅ Found 1 episodes: [1]
# 📡 Fetching geometry for episode 1...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1101664 geometry unified successfully
# ✅ Event 1101664 processed successfully
#
# 📍 Processing event 29/306: 1336287
#
# 🔄 Processing event 1336287 (EQ)...
# 🔍 Fetching episodes for event 1336287...
# ✅ Found 1 episodes: [1460216]
# 📡 Fetching geometry for episode 1460216...
# ✅ Retrieved 8 geometry objects
# 🔧 Unifying 8 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1336287 geometry unified successfully
# ✅ Event 1336287 processed successfully
#
# 📍 Processing event 30/306: 1000905
#
# 🔄 Processing event 1000905 (TC)...
# 🔍 Fetching episodes for event 1000905...
# ✅ Found 1 episodes: [16]
# 📡 Fetching geometry for episode 16...
# ✅ Retrieved 39 geometry objects
# 🔧 Unifying 39 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000905 geometry unified successfully
# ✅ Event 1000905 processed successfully
#
# 📍 Processing event 31/306: 1000891
#
# 🔄 Processing event 1000891 (TC)...
# 🔍 Fetching episodes for event 1000891...
# ✅ Found 1 episodes: [12]
# 📡 Fetching geometry for episode 12...
# ✅ Retrieved 34 geometry objects
# 🔧 Unifying 34 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000891 geometry unified successfully
# ✅ Event 1000891 processed successfully
#
# 📍 Processing event 32/306: 1101446
#
# 🔄 Processing event 1101446 (FL)...
# 🔍 Fetching episodes for event 1101446...
# ✅ Found 1 episodes: [8]
# 📡 Fetching geometry for episode 8...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1101446 geometry unified successfully
# ✅ Event 1101446 processed successfully
#
# 📍 Processing event 33/306: 1304967
#
# 🔄 Processing event 1304967 (EQ)...
# 🔍 Fetching episodes for event 1304967...
# ✅ Found 1 episodes: [1420359]
# 📡 Fetching geometry for episode 1420359...
# ✅ Retrieved 10 geometry objects
# 🔧 Unifying 10 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1304967 geometry unified successfully
# ✅ Event 1304967 processed successfully
#
# 📍 Processing event 34/306: 1000839
#
# 🔄 Processing event 1000839 (TC)...
# 🔍 Fetching episodes for event 1000839...
# ✅ Found 1 episodes: [18]
# 📡 Fetching geometry for episode 18...
# ✅ Retrieved 42 geometry objects
# 🔧 Unifying 42 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000839 geometry unified successfully
# ✅ Event 1000839 processed successfully
#
# 📍 Processing event 35/306: 1000837
#
# 🔄 Processing event 1000837 (TC)...
# 🔍 Fetching episodes for event 1000837...
# ✅ Found 1 episodes: [13]
# 📡 Fetching geometry for episode 13...
# ✅ Retrieved 32 geometry objects
# 🔧 Unifying 32 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000837 geometry unified successfully
# ✅ Event 1000837 processed successfully
#
# 📍 Processing event 36/306: 1101109
#
# 🔄 Processing event 1101109 (FL)...
# 🔍 Fetching episodes for event 1101109...
# ✅ Found 1 episodes: [3]
# 📡 Fetching geometry for episode 3...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1101109 geometry unified successfully
# ✅ Event 1101109 processed successfully
#
# 📍 Processing event 37/306: 1000824
#
# 🔄 Processing event 1000824 (TC)...
# 🔍 Fetching episodes for event 1000824...
# ✅ Found 1 episodes: [48]
# 📡 Fetching geometry for episode 48...
# ✅ Retrieved 104 geometry objects
# 🔧 Unifying 104 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000824 geometry unified successfully
# ✅ Event 1000824 processed successfully
#
# 📍 Processing event 38/306: 1285804
#
# 🔄 Processing event 1285804 (EQ)...
# 🔍 Fetching episodes for event 1285804...
# ✅ Found 1 episodes: [1396900]
# 📡 Fetching geometry for episode 1396900...
# ✅ Retrieved 7 geometry objects
# 🔧 Unifying 7 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1285804 geometry unified successfully
# ✅ Event 1285804 processed successfully
#
# 📍 Processing event 39/306: 1101085
#
# 🔄 Processing event 1101085 (FL)...
# 🔍 Fetching episodes for event 1101085...
# ✅ Found 1 episodes: [2]
# 📡 Fetching geometry for episode 2...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1101085 geometry unified successfully
# ✅ Event 1101085 processed successfully
#
# 📍 Processing event 40/306: 1101029
#
# 🔄 Processing event 1101029 (FL)...
# 🔍 Fetching episodes for event 1101029...
# ✅ Found 1 episodes: [5]
# 📡 Fetching geometry for episode 5...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1101029 geometry unified successfully
# ✅ Event 1101029 processed successfully
#
# 📍 Processing event 41/306: 1100932
#
# 🔄 Processing event 1100932 (FL)...
# 🔍 Fetching episodes for event 1100932...
# ✅ Found 1 episodes: [7]
# 📡 Fetching geometry for episode 7...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1100932 geometry unified successfully
# ✅ Event 1100932 processed successfully
#
# 📍 Processing event 42/306: 1000799
#
# 🔄 Processing event 1000799 (TC)...
# 🔍 Fetching episodes for event 1000799...
# ✅ Found 1 episodes: [41]
# 📡 Fetching geometry for episode 41...
# ✅ Retrieved 97 geometry objects
# 🔧 Unifying 97 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000799 geometry unified successfully
# ✅ Event 1000799 processed successfully
#
# 📍 Processing event 43/306: 1000801
#
# 🔄 Processing event 1000801 (TC)...
# 🔍 Fetching episodes for event 1000801...
# ✅ Found 1 episodes: [21]
# 📡 Fetching geometry for episode 21...
# ✅ Retrieved 48 geometry objects
# 🔧 Unifying 48 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000801 geometry unified successfully
# ✅ Event 1000801 processed successfully
#
# 📍 Processing event 44/306: 1000787
#
# 🔄 Processing event 1000787 (TC)...
# 🔍 Fetching episodes for event 1000787...
# ✅ Found 1 episodes: [4]
# 📡 Fetching geometry for episode 4...
# ✅ Retrieved 14 geometry objects
# 🔧 Unifying 14 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000787 geometry unified successfully
# ✅ Event 1000787 processed successfully
#
# 📍 Processing event 45/306: 1269701
#
# 🔄 Processing event 1269701 (EQ)...
# 🔍 Fetching episodes for event 1269701...
# ✅ Found 1 episodes: [1376352]
# 📡 Fetching geometry for episode 1376352...
# ✅ Retrieved 9 geometry objects
# 🔧 Unifying 9 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1269701 geometry unified successfully
# ✅ Event 1269701 processed successfully
#
# 📍 Processing event 46/306: 1269679
#
# 🔄 Processing event 1269679 (EQ)...
# 🔍 Fetching episodes for event 1269679...
# ✅ Found 1 episodes: [1376314]
# 📡 Fetching geometry for episode 1376314...
# ✅ Retrieved 10 geometry objects
# 🔧 Unifying 10 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1269679 geometry unified successfully
# ✅ Event 1269679 processed successfully
#
# 📍 Processing event 47/306: 1000730
#
# 🔄 Processing event 1000730 (TC)...
# 🔍 Fetching episodes for event 1000730...
# ✅ Found 1 episodes: [10]
# 📡 Fetching geometry for episode 10...
# ✅ Retrieved 29 geometry objects
# 🔧 Unifying 29 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000730 geometry unified successfully
# ✅ Event 1000730 processed successfully
#
# 📍 Processing event 48/306: 1000717
#
# 🔄 Processing event 1000717 (TC)...
# 🔍 Fetching episodes for event 1000717...
# ✅ Found 1 episodes: [12]
# 📡 Fetching geometry for episode 12...
# ✅ Retrieved 31 geometry objects
# 🔧 Unifying 31 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000717 geometry unified successfully
# ✅ Event 1000717 processed successfully
#
# 📍 Processing event 49/306: 1000706
#
# 🔄 Processing event 1000706 (TC)...
# 🔍 Fetching episodes for event 1000706...
# ✅ Found 1 episodes: [29]
# 📡 Fetching geometry for episode 29...
# ✅ Retrieved 66 geometry objects
# 🔧 Unifying 66 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000706 geometry unified successfully
# ✅ Event 1000706 processed successfully
#
# 📍 Processing event 50/306: 1000705
#
# 🔄 Processing event 1000705 (TC)...
# 🔍 Fetching episodes for event 1000705...
# ✅ Found 1 episodes: [24]
# 📡 Fetching geometry for episode 24...
# ✅ Retrieved 56 geometry objects
# 🔧 Unifying 56 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000705 geometry unified successfully
# ✅ Event 1000705 processed successfully
#
# 📍 Processing event 51/306: 1000702
#
# 🔄 Processing event 1000702 (TC)...
# 🔍 Fetching episodes for event 1000702...
# ✅ Found 1 episodes: [24]
# 📡 Fetching geometry for episode 24...
# ✅ Retrieved 56 geometry objects
# 🔧 Unifying 56 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000702 geometry unified successfully
# ✅ Event 1000702 processed successfully
#
# 📍 Processing event 52/306: 1000693
#
# 🔄 Processing event 1000693 (TC)...
# 🔍 Fetching episodes for event 1000693...
# ✅ Found 1 episodes: [7]
# 📡 Fetching geometry for episode 7...
# ✅ Retrieved 22 geometry objects
# 🔧 Unifying 22 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000693 geometry unified successfully
# ✅ Event 1000693 processed successfully
#
# 📍 Processing event 53/306: 1100581
#
# 🔄 Processing event 1100581 (FL)...
# 🔍 Fetching episodes for event 1100581...
# ✅ Found 1 episodes: [1]
# 📡 Fetching geometry for episode 1...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1100581 geometry unified successfully
# ✅ Event 1100581 processed successfully
#
# 📍 Processing event 54/306: 1000688
#
# 🔄 Processing event 1000688 (TC)...
# 🔍 Fetching episodes for event 1000688...
# ✅ Found 1 episodes: [15]
# 📡 Fetching geometry for episode 15...
# ✅ Retrieved 38 geometry objects
# 🔧 Unifying 38 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000688 geometry unified successfully
# ✅ Event 1000688 processed successfully
#
# 📍 Processing event 55/306: 1000689
#
# 🔄 Processing event 1000689 (TC)...
# 🔍 Fetching episodes for event 1000689...
# ✅ Found 1 episodes: [5]
# 📡 Fetching geometry for episode 5...
# ✅ Retrieved 16 geometry objects
# 🔧 Unifying 16 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000689 geometry unified successfully
# ✅ Event 1000689 processed successfully
#
# 📍 Processing event 56/306: 1100514
#
# 🔄 Processing event 1100514 (FL)...
# 🔍 Fetching episodes for event 1100514...
# ✅ Found 1 episodes: [7]
# 📡 Fetching geometry for episode 7...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1100514 geometry unified successfully
# ✅ Event 1100514 processed successfully
#
# 📍 Processing event 57/306: 1202436
#
# 🔄 Processing event 1202436 (EQ)...
# 🔍 Fetching episodes for event 1202436...
# ✅ Found 1 episodes: [1291292]
# 📡 Fetching geometry for episode 1291292...
# ✅ Retrieved 9 geometry objects
# 🔧 Unifying 9 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1202436 geometry unified successfully
# ✅ Event 1202436 processed successfully
#
# 📍 Processing event 58/306: 1013258
#
# 🔄 Processing event 1013258 (DR)...
# 🔍 Fetching episodes for event 1013258...
# ✅ Found 1 episodes: [9]
# 📡 Fetching geometry for episode 9...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1013258 geometry unified successfully
# ✅ Event 1013258 processed successfully
#
# 📍 Processing event 59/306: 1000609
#
# 🔄 Processing event 1000609 (TC)...
# 🔍 Fetching episodes for event 1000609...
# ✅ Found 1 episodes: [25]
# 📡 Fetching geometry for episode 25...
# ✅ Retrieved 60 geometry objects
# 🔧 Unifying 60 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000609 geometry unified successfully
# ✅ Event 1000609 processed successfully
#
# 📍 Processing event 60/306: 1000605
#
# 🔄 Processing event 1000605 (TC)...
# 🔍 Fetching episodes for event 1000605...
# ✅ Found 1 episodes: [16]
# 📡 Fetching geometry for episode 16...
# ✅ Retrieved 39 geometry objects
# 🔧 Unifying 39 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000605 geometry unified successfully
# ✅ Event 1000605 processed successfully
#
# 📍 Processing event 61/306: 1000593
#
# 🔄 Processing event 1000593 (TC)...
# 🔍 Fetching episodes for event 1000593...
# ✅ Found 1 episodes: [22]
# 📡 Fetching geometry for episode 22...
# ✅ Retrieved 52 geometry objects
# 🔧 Unifying 52 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000593 geometry unified successfully
# ✅ Event 1000593 processed successfully
#
# 📍 Processing event 62/306: 1000589
#
# 🔄 Processing event 1000589 (TC)...
# 🔍 Fetching episodes for event 1000589...
# ✅ Found 1 episodes: [14]
# 📡 Fetching geometry for episode 14...
# ✅ Retrieved 34 geometry objects
# 🔧 Unifying 34 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000589 geometry unified successfully
# ✅ Event 1000589 processed successfully
#
# 📍 Processing event 63/306: 1100113
#
# 🔄 Processing event 1100113 (FL)...
# 🔍 Fetching episodes for event 1100113...
# ✅ Found 1 episodes: [3]
# 📡 Fetching geometry for episode 3...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1100113 geometry unified successfully
# ✅ Event 1100113 processed successfully
#
# 📍 Processing event 64/306: 1000582
#
# 🔄 Processing event 1000582 (TC)...
# 🔍 Fetching episodes for event 1000582...
# ✅ Found 1 episodes: [31]
# 📡 Fetching geometry for episode 31...
# ✅ Retrieved 70 geometry objects
# 🔧 Unifying 70 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000582 geometry unified successfully
# ✅ Event 1000582 processed successfully
#
# 📍 Processing event 65/306: 1000579
#
# 🔄 Processing event 1000579 (TC)...
# 🔍 Fetching episodes for event 1000579...
# ✅ Found 1 episodes: [14]
# 📡 Fetching geometry for episode 14...
# ✅ Retrieved 34 geometry objects
# 🔧 Unifying 34 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000579 geometry unified successfully
# ✅ Event 1000579 processed successfully
#
# 📍 Processing event 66/306: 1000573
#
# 🔄 Processing event 1000573 (TC)...
# 🔍 Fetching episodes for event 1000573...
# ✅ Found 1 episodes: [18]
# 📡 Fetching geometry for episode 18...
# ✅ Retrieved 42 geometry objects
# 🔧 Unifying 42 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000573 geometry unified successfully
# ✅ Event 1000573 processed successfully
#
# 📍 Processing event 67/306: 1182839
#
# 🔄 Processing event 1182839 (EQ)...
# 🔍 Fetching episodes for event 1182839...
# ✅ Found 1 episodes: [1264685]
# 📡 Fetching geometry for episode 1264685...
# ✅ Retrieved 9 geometry objects
# 🔧 Unifying 9 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1182839 geometry unified successfully
# ✅ Event 1182839 processed successfully
#
# 📍 Processing event 68/306: 1100137
#
# 🔄 Processing event 1100137 (FL)...
# 🔍 Fetching episodes for event 1100137...
# ✅ Found 1 episodes: [1]
# 📡 Fetching geometry for episode 1...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1100137 geometry unified successfully
# ✅ Event 1100137 processed successfully
#
# 📍 Processing event 69/306: 1012538
#
# 🔄 Processing event 1012538 (DR)...
# 🔍 Fetching episodes for event 1012538...
# ✅ Found 1 episodes: [20]
# 📡 Fetching geometry for episode 20...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1012538 geometry unified successfully
# ✅ Event 1012538 processed successfully
#
# 📍 Processing event 70/306: 1000514
#
# 🔄 Processing event 1000514 (TC)...
# 🔍 Fetching episodes for event 1000514...
# ✅ Found 1 episodes: [36]
# 📡 Fetching geometry for episode 36...
# ✅ Retrieved 77 geometry objects
# 🔧 Unifying 77 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000514 geometry unified successfully
# ✅ Event 1000514 processed successfully
#
# 📍 Processing event 71/306: 1000498
#
# 🔄 Processing event 1000498 (TC)...
# 🔍 Fetching episodes for event 1000498...
# ✅ Found 1 episodes: [39]
# 📡 Fetching geometry for episode 39...
# ✅ Retrieved 90 geometry objects
# 🔧 Unifying 90 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000498 geometry unified successfully
# ✅ Event 1000498 processed successfully
#
# 📍 Processing event 72/306: 1000502
#
# 🔄 Processing event 1000502 (TC)...
# 🔍 Fetching episodes for event 1000502...
# ✅ Found 1 episodes: [17]
# 📡 Fetching geometry for episode 17...
# ✅ Retrieved 37 geometry objects
# 🔧 Unifying 37 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000502 geometry unified successfully
# ✅ Event 1000502 processed successfully
#
# 📍 Processing event 73/306: 1000485
#
# 🔄 Processing event 1000485 (TC)...
# 🔍 Fetching episodes for event 1000485...
# ✅ Found 1 episodes: [19]
# 📡 Fetching geometry for episode 19...
# ✅ Retrieved 42 geometry objects
# 🔧 Unifying 42 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000485 geometry unified successfully
# ✅ Event 1000485 processed successfully
#
# 📍 Processing event 74/306: 1000469
#
# 🔄 Processing event 1000469 (TC)...
# 🔍 Fetching episodes for event 1000469...
# ✅ Found 1 episodes: [26]
# 📡 Fetching geometry for episode 26...
# ✅ Retrieved 55 geometry objects
# 🔧 Unifying 55 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000469 geometry unified successfully
# ✅ Event 1000469 processed successfully
#
# 📍 Processing event 75/306: 1000466
#
# 🔄 Processing event 1000466 (TC)...
# 🔍 Fetching episodes for event 1000466...
# ✅ Found 1 episodes: [34]
# 📡 Fetching geometry for episode 34...
# ✅ Retrieved 75 geometry objects
# 🔧 Unifying 75 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000466 geometry unified successfully
# ✅ Event 1000466 processed successfully
#
# 📍 Processing event 76/306: 1000411
#
# 🔄 Processing event 1000411 (TC)...
# 🔍 Fetching episodes for event 1000411...
# ✅ Found 1 episodes: [17]
# 📡 Fetching geometry for episode 17...
# ✅ Retrieved 39 geometry objects
# 🔧 Unifying 39 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000411 geometry unified successfully
# ✅ Event 1000411 processed successfully
#
# 📍 Processing event 77/306: 1000389
#
# 🔄 Processing event 1000389 (TC)...
# 🔍 Fetching episodes for event 1000389...
# ✅ Found 1 episodes: [14]
# 📡 Fetching geometry for episode 14...
# ✅ Retrieved 34 geometry objects
# 🔧 Unifying 34 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000389 geometry unified successfully
# ✅ Event 1000389 processed successfully
#
# 📍 Processing event 78/306: 1000378
#
# 🔄 Processing event 1000378 (TC)...
# 🔍 Fetching episodes for event 1000378...
# ✅ Found 1 episodes: [17]
# 📡 Fetching geometry for episode 17...
# ✅ Retrieved 39 geometry objects
# 🔧 Unifying 39 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000378 geometry unified successfully
# ✅ Event 1000378 processed successfully
#
# 📍 Processing event 79/306: 1000368
#
# 🔄 Processing event 1000368 (TC)...
# 🔍 Fetching episodes for event 1000368...
# ✅ Found 1 episodes: [6]
# 📡 Fetching geometry for episode 6...
# ✅ Retrieved 16 geometry objects
# 🔧 Unifying 16 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000368 geometry unified successfully
# ✅ Event 1000368 processed successfully
#
# 📍 Processing event 80/306: 1000321
#
# 🔄 Processing event 1000321 (TC)...
# 🔍 Fetching episodes for event 1000321...
# ✅ Found 1 episodes: [27]
# 📡 Fetching geometry for episode 27...
# ✅ Retrieved 59 geometry objects
# 🔧 Unifying 59 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000321 geometry unified successfully
# ✅ Event 1000321 processed successfully
#
# 📍 Processing event 81/306: 1000320
#
# 🔄 Processing event 1000320 (TC)...
# 🔍 Fetching episodes for event 1000320...
# ✅ Found 1 episodes: [28]
# 📡 Fetching geometry for episode 28...
# ✅ Retrieved 61 geometry objects
# 🔧 Unifying 61 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000320 geometry unified successfully
# ✅ Event 1000320 processed successfully
#
# 📍 Processing event 82/306: 1000312
#
# 🔄 Processing event 1000312 (TC)...
# 🔍 Fetching episodes for event 1000312...
# ✅ Found 1 episodes: [20]
# 📡 Fetching geometry for episode 20...
# ✅ Retrieved 45 geometry objects
# 🔧 Unifying 45 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000312 geometry unified successfully
# ✅ Event 1000312 processed successfully
#
# 📍 Processing event 83/306: 1000302
#
# 🔄 Processing event 1000302 (TC)...
# 🔍 Fetching episodes for event 1000302...
# ✅ Found 1 episodes: [25]
# 📡 Fetching geometry for episode 25...
# ✅ Retrieved 58 geometry objects
# 🔧 Unifying 58 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000302 geometry unified successfully
# ✅ Event 1000302 processed successfully
#
# 📍 Processing event 84/306: 1000291
#
# 🔄 Processing event 1000291 (TC)...
# 🔍 Fetching episodes for event 1000291...
# ✅ Found 1 episodes: [6]
# 📡 Fetching geometry for episode 6...
# ✅ Retrieved 15 geometry objects
# 🔧 Unifying 15 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000291 geometry unified successfully
# ✅ Event 1000291 processed successfully
#
# 📍 Processing event 85/306: 4370
#
# 🔄 Processing event 4370 (FL)...
# 🔍 Fetching episodes for event 4370...
# ✅ Found 1 episodes: [2]
# 📡 Fetching geometry for episode 2...
# ✅ Retrieved 1 geometry objects
# 🔧 Unifying 1 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 4370 geometry unified successfully
# ✅ Event 4370 processed successfully
#
# 📍 Processing event 86/306: 1080050
#
# 🔄 Processing event 1080050 (EQ)...
# 🔍 Fetching episodes for event 1080050...
# ✅ Found 1 episodes: [1118615]
# 📡 Fetching geometry for episode 1118615...
# ✅ Retrieved 9 geometry objects
# 🔧 Unifying 9 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1080050 geometry unified successfully
# ✅ Event 1080050 processed successfully
#
# 📍 Processing event 87/306: 1000221
#
# 🔄 Processing event 1000221 (TC)...
# 🔍 Fetching episodes for event 1000221...
# ✅ Found 1 episodes: [15]
# 📡 Fetching geometry for episode 15...
# ✅ Retrieved 24 geometry objects
# 🔧 Unifying 24 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000221 geometry unified successfully
# ✅ Event 1000221 processed successfully
#
# 📍 Processing event 88/306: 1000217
#
# 🔄 Processing event 1000217 (TC)...
# 🔍 Fetching episodes for event 1000217...
# ✅ Found 1 episodes: [30]
# 📡 Fetching geometry for episode 30...
# ✅ Retrieved 41 geometry objects
# 🔧 Unifying 41 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000217 geometry unified successfully
# ✅ Event 1000217 processed successfully
#
# 📍 Processing event 89/306: 1000191
#
# 🔄 Processing event 1000191 (TC)...
# 🔍 Fetching episodes for event 1000191...
# ✅ Found 1 episodes: [39]
# 📡 Fetching geometry for episode 39...
# ✅ Retrieved 48 geometry objects
# 🔧 Unifying 48 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000191 geometry unified successfully
# ✅ Event 1000191 processed successfully
#
# 📍 Processing event 90/306: 1000172
#
# 🔄 Processing event 1000172 (TC)...
# 🔍 Fetching episodes for event 1000172...
# ✅ Found 1 episodes: [50]
# 📡 Fetching geometry for episode 50...
# ✅ Retrieved 58 geometry objects
# 🔧 Unifying 58 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000172 geometry unified successfully
# ✅ Event 1000172 processed successfully
#
# 📍 Processing event 91/306: 4249
#
# 🔄 Processing event 4249 (FL)...
# 🔍 Fetching episodes for event 4249...
# ✅ Found 1 episodes: [6]
# 📡 Fetching geometry for episode 6...
# ✅ Retrieved 1 geometry objects
# 🔧 Unifying 1 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 4249 geometry unified successfully
# ✅ Event 4249 processed successfully
#
# 📍 Processing event 92/306: 47823
#
# 🔄 Processing event 47823 (TC)...
# 🔍 Fetching episodes for event 47823...
# ✅ Found 1 episodes: [25]
# 📡 Fetching geometry for episode 25...
# ✅ Retrieved 4 geometry objects
# 🔧 Unifying 4 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 47823 geometry unified successfully
# ✅ Event 47823 processed successfully
#
# 📍 Processing event 93/306: 4185
#
# 🔄 Processing event 4185 (FL)...
# 🔍 Fetching episodes for event 4185...
# ✅ Found 1 episodes: [2]
# 📡 Fetching geometry for episode 2...
# ✅ Retrieved 1 geometry objects
# 🔧 Unifying 1 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 4185 geometry unified successfully
# ✅ Event 4185 processed successfully
#
# 📍 Processing event 94/306: 4167
#
# 🔄 Processing event 4167 (FL)...
# 🔍 Fetching episodes for event 4167...
# ✅ Found 1 episodes: [2]
# 📡 Fetching geometry for episode 2...
# ✅ Retrieved 1 geometry objects
# 🔧 Unifying 1 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 4167 geometry unified successfully
# ✅ Event 4167 processed successfully
#
# 📍 Processing event 95/306: 46757
#
# 🔄 Processing event 46757 (TC)...
# 🔍 Fetching episodes for event 46757...
# ✅ Found 1 episodes: [25]
# 📡 Fetching geometry for episode 25...
# ✅ Retrieved 4 geometry objects
# 🔧 Unifying 4 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 46757 geometry unified successfully
# ✅ Event 46757 processed successfully
#
# 📍 Processing event 96/306: 46636
#
# 🔄 Processing event 46636 (TC)...
# 🔍 Fetching episodes for event 46636...
# ✅ Found 1 episodes: [35]
# 📡 Fetching geometry for episode 35...
# ✅ Retrieved 4 geometry objects
# 🔧 Unifying 4 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 46636 geometry unified successfully
# ✅ Event 46636 processed successfully
#
# 📍 Processing event 97/306: 4155
#
# 🔄 Processing event 4155 (FL)...
# 🔍 Fetching episodes for event 4155...
# ✅ Found 1 episodes: [2]
# 📡 Fetching geometry for episode 2...
# ✅ Retrieved 1 geometry objects
# 🔧 Unifying 1 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 4155 geometry unified successfully
# ✅ Event 4155 processed successfully
#
# 📍 Processing event 98/306: 41058
#
# 🔄 Processing event 41058 (TC)...
# 🔍 Fetching episodes for event 41058...
# ✅ Found 1 episodes: [32]
# 📡 Fetching geometry for episode 32...
# ✅ Retrieved 4 geometry objects
# 🔧 Unifying 4 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 41058 geometry unified successfully
# ✅ Event 41058 processed successfully
#
# 📍 Processing event 99/306: 1010636
#
# 🔄 Processing event 1010636 (EQ)...
# 🔍 Fetching episodes for event 1010636...
# ✅ Found 1 episodes: [1019554]
# 📡 Fetching geometry for episode 1019554...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1010636 geometry unified successfully
# ✅ Event 1010636 processed successfully
#
# 📍 Processing event 100/306: 4083
#
# 🔄 Processing event 4083 (FL)...
# 🔍 Fetching episodes for event 4083...
# ✅ Found 1 episodes: [6]
# 📡 Fetching geometry for episode 6...
# ✅ Retrieved 1 geometry objects
# 🔧 Unifying 1 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 4083 geometry unified successfully
# ✅ Event 4083 processed successfully
#
# 📍 Processing event 101/306: 1001131
#
# 🔄 Processing event 1001131 (TC)...
# 🔍 Fetching episodes for event 1001131...
# ✅ Found 1 episodes: [29]
# 📡 Fetching geometry for episode 29...
# ✅ Retrieved 66 geometry objects
# 🔧 Unifying 66 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001131 geometry unified successfully
# ✅ Event 1001131 processed successfully
#
# 📍 Processing event 102/306: 1001130
#
# 🔄 Processing event 1001130 (TC)...
# 🔍 Fetching episodes for event 1001130...
# ✅ Found 1 episodes: [7]
# 📡 Fetching geometry for episode 7...
# ✅ Retrieved 19 geometry objects
# 🔧 Unifying 19 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001130 geometry unified successfully
# ✅ Event 1001130 processed successfully
#
# 📍 Processing event 103/306: 1102974
#
# 🔄 Processing event 1102974 (FL)...
# 🔍 Fetching episodes for event 1102974...
# ✅ Found 1 episodes: [2]
# 📡 Fetching geometry for episode 2...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1102974 geometry unified successfully
# ✅ Event 1102974 processed successfully
#
# 📍 Processing event 104/306: 1001117
#
# 🔄 Processing event 1001117 (TC)...
# 🔍 Fetching episodes for event 1001117...
# ✅ Found 1 episodes: [8]
# 📡 Fetching geometry for episode 8...
# ✅ Retrieved 26 geometry objects
# 🔧 Unifying 26 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001117 geometry unified successfully
# ✅ Event 1001117 processed successfully
#
# 📍 Processing event 105/306: 1102678
#
# 🔄 Processing event 1102678 (FL)...
# 🔍 Fetching episodes for event 1102678...
# ✅ Found 1 episodes: [30]
# 📡 Fetching geometry for episode 30...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1102678 geometry unified successfully
# ✅ Event 1102678 processed successfully
#
# 📍 Processing event 106/306: 1001089
#
# 🔄 Processing event 1001089 (TC)...
# 🔍 Fetching episodes for event 1001089...
# ✅ Found 1 episodes: [11]
# 📡 Fetching geometry for episode 11...
# ✅ Retrieved 26 geometry objects
# 🔧 Unifying 26 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001089 geometry unified successfully
# ✅ Event 1001089 processed successfully
#
# 📍 Processing event 107/306: 1001064
#
# 🔄 Processing event 1001064 (TC)...
# 🔍 Fetching episodes for event 1001064...
# ✅ Found 1 episodes: [6]
# 📡 Fetching geometry for episode 6...
# ✅ Retrieved 21 geometry objects
# 🔧 Unifying 21 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001064 geometry unified successfully
# ✅ Event 1001064 processed successfully
#
# 📍 Processing event 108/306: 1001041
#
# 🔄 Processing event 1001041 (TC)...
# 🔍 Fetching episodes for event 1001041...
# ✅ Found 1 episodes: [27]
# 📡 Fetching geometry for episode 27...
# ✅ Retrieved 67 geometry objects
# 🔧 Unifying 67 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001041 geometry unified successfully
# ✅ Event 1001041 processed successfully
#
# 📍 Processing event 109/306: 1001037
#
# 🔄 Processing event 1001037 (TC)...
# 🔍 Fetching episodes for event 1001037...
# ✅ Found 1 episodes: [8]
# 📡 Fetching geometry for episode 8...
# ✅ Retrieved 25 geometry objects
# 🔧 Unifying 25 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001037 geometry unified successfully
# ✅ Event 1001037 processed successfully
#
# 📍 Processing event 110/306: 1001034
#
# 🔄 Processing event 1001034 (TC)...
# 🔍 Fetching episodes for event 1001034...
# ✅ Found 1 episodes: [4]
# 📡 Fetching geometry for episode 4...
# ✅ Retrieved 12 geometry objects
# 🔧 Unifying 12 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001034 geometry unified successfully
# ✅ Event 1001034 processed successfully
#
# 📍 Processing event 111/306: 1001029
#
# 🔄 Processing event 1001029 (TC)...
# 🔍 Fetching episodes for event 1001029...
# ✅ Found 1 episodes: [7]
# 📡 Fetching geometry for episode 7...
# ✅ Retrieved 22 geometry objects
# 🔧 Unifying 22 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001029 geometry unified successfully
# ✅ Event 1001029 processed successfully
#
# 📍 Processing event 112/306: 1000987
#
# 🔄 Processing event 1000987 (TC)...
# 🔍 Fetching episodes for event 1000987...
# ✅ Found 1 episodes: [3]
# 📡 Fetching geometry for episode 3...
# ✅ Retrieved 10 geometry objects
# 🔧 Unifying 10 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000987 geometry unified successfully
# ✅ Event 1000987 processed successfully
#
# 📍 Processing event 113/306: 1102135
#
# 🔄 Processing event 1102135 (FL)...
# 🔍 Fetching episodes for event 1102135...
# ✅ Found 1 episodes: [3]
# 📡 Fetching geometry for episode 3...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1102135 geometry unified successfully
# ✅ Event 1102135 processed successfully
#
# 📍 Processing event 114/306: 1102077
#
# 🔄 Processing event 1102077 (FL)...
# 🔍 Fetching episodes for event 1102077...
# ✅ Found 1 episodes: [1]
# 📡 Fetching geometry for episode 1...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1102077 geometry unified successfully
# ✅ Event 1102077 processed successfully
#
# 📍 Processing event 115/306: 1000975
#
# 🔄 Processing event 1000975 (TC)...
# 🔍 Fetching episodes for event 1000975...
# ✅ Found 1 episodes: [39]
# 📡 Fetching geometry for episode 39...
# ✅ Retrieved 88 geometry objects
# 🔧 Unifying 88 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000975 geometry unified successfully
# ✅ Event 1000975 processed successfully
#
# 📍 Processing event 116/306: 1102000
#
# 🔄 Processing event 1102000 (FL)...
# 🔍 Fetching episodes for event 1102000...
# ✅ Found 1 episodes: [1]
# 📡 Fetching geometry for episode 1...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1102000 geometry unified successfully
# ✅ Event 1102000 processed successfully
#
# 📍 Processing event 117/306: 1000950
#
# 🔄 Processing event 1000950 (TC)...
# 🔍 Fetching episodes for event 1000950...
# ✅ Found 1 episodes: [10]
# 📡 Fetching geometry for episode 10...
# ✅ Retrieved 27 geometry objects
# 🔧 Unifying 27 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000950 geometry unified successfully
# ✅ Event 1000950 processed successfully
#
# 📍 Processing event 118/306: 1000941
#
# 🔄 Processing event 1000941 (TC)...
# 🔍 Fetching episodes for event 1000941...
# ✅ Found 1 episodes: [6]
# 📡 Fetching geometry for episode 6...
# ✅ Retrieved 16 geometry objects
# 🔧 Unifying 16 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000941 geometry unified successfully
# ✅ Event 1000941 processed successfully
#
# 📍 Processing event 119/306: 1101588
#
# 🔄 Processing event 1101588 (FL)...
# 🔍 Fetching episodes for event 1101588...
# ✅ Found 1 episodes: [7]
# 📡 Fetching geometry for episode 7...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1101588 geometry unified successfully
# ✅ Event 1101588 processed successfully
#
# 📍 Processing event 120/306: 1000904
#
# 🔄 Processing event 1000904 (TC)...
# 🔍 Fetching episodes for event 1000904...
# ✅ Found 1 episodes: [5]
# 📡 Fetching geometry for episode 5...
# ✅ Retrieved 16 geometry objects
# 🔧 Unifying 16 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000904 geometry unified successfully
# ✅ Event 1000904 processed successfully
#
# 📍 Processing event 121/306: 1000883
#
# 🔄 Processing event 1000883 (TC)...
# 🔍 Fetching episodes for event 1000883...
# ✅ Found 1 episodes: [18]
# 📡 Fetching geometry for episode 18...
# ✅ Retrieved 44 geometry objects
# 🔧 Unifying 44 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000883 geometry unified successfully
# ✅ Event 1000883 processed successfully
#
# 📍 Processing event 122/306: 1000858
#
# 🔄 Processing event 1000858 (TC)...
# 🔍 Fetching episodes for event 1000858...
# ✅ Found 1 episodes: [3]
# 📡 Fetching geometry for episode 3...
# ✅ Retrieved 12 geometry objects
# 🔧 Unifying 12 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000858 geometry unified successfully
# ✅ Event 1000858 processed successfully
#
# 📍 Processing event 123/306: 1101164
#
# 🔄 Processing event 1101164 (FL)...
# 🔍 Fetching episodes for event 1101164...
# ✅ Found 1 episodes: [2]
# 📡 Fetching geometry for episode 2...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1101164 geometry unified successfully
# ✅ Event 1101164 processed successfully
#
# 📍 Processing event 124/306: 1101125
#
# 🔄 Processing event 1101125 (FL)...
# 🔍 Fetching episodes for event 1101125...
# ✅ Found 1 episodes: [3]
# 📡 Fetching geometry for episode 3...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1101125 geometry unified successfully
# ✅ Event 1101125 processed successfully
#
# 📍 Processing event 125/306: 1100977
#
# 🔄 Processing event 1100977 (FL)...
# 🔍 Fetching episodes for event 1100977...
# ✅ Found 1 episodes: [26]
# 📡 Fetching geometry for episode 26...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1100977 geometry unified successfully
# ✅ Event 1100977 processed successfully
#
# 📍 Processing event 126/306: 1100902
#
# 🔄 Processing event 1100902 (FL)...
# 🔍 Fetching episodes for event 1100902...
# ✅ Found 1 episodes: [1]
# 📡 Fetching geometry for episode 1...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1100902 geometry unified successfully
# ✅ Event 1100902 processed successfully
#
# 📍 Processing event 127/306: 1000784
#
# 🔄 Processing event 1000784 (TC)...
# 🔍 Fetching episodes for event 1000784...
# ✅ Found 1 episodes: [10]
# 📡 Fetching geometry for episode 10...
# ✅ Retrieved 28 geometry objects
# 🔧 Unifying 28 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000784 geometry unified successfully
# ✅ Event 1000784 processed successfully
#
# 📍 Processing event 128/306: 1000782
#
# 🔄 Processing event 1000782 (TC)...
# 🔍 Fetching episodes for event 1000782...
# ✅ Found 1 episodes: [15]
# 📡 Fetching geometry for episode 15...
# ✅ Retrieved 40 geometry objects
# 🔧 Unifying 40 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000782 geometry unified successfully
# ✅ Event 1000782 processed successfully
#
# 📍 Processing event 129/306: 1100883
#
# 🔄 Processing event 1100883 (FL)...
# 🔍 Fetching episodes for event 1100883...
# ✅ Found 1 episodes: [4]
# 📡 Fetching geometry for episode 4...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1100883 geometry unified successfully
# ✅ Event 1100883 processed successfully
#
# 📍 Processing event 130/306: 1266651
#
# 🔄 Processing event 1266651 (EQ)...
# 🔍 Fetching episodes for event 1266651...
# ✅ Found 1 episodes: [1372484]
# 📡 Fetching geometry for episode 1372484...
# ✅ Retrieved 9 geometry objects
# 🔧 Unifying 9 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1266651 geometry unified successfully
# ✅ Event 1266651 processed successfully
#
# 📍 Processing event 131/306: 1100755
#
# 🔄 Processing event 1100755 (FL)...
# 🔍 Fetching episodes for event 1100755...
# ✅ Found 1 episodes: [2]
# 📡 Fetching geometry for episode 2...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1100755 geometry unified successfully
# ...
#
# 🔄 Processing event 113603 (EQ)...
# 🔍 Fetching episodes for event 113603...
# ✅ Found 1 episodes: [113605]
# 📡 Fetching geometry for episode 113605...
# ✅ Retrieved 8 geometry objects
# 🔧 Unifying 8 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 113603 geometry unified successfully
# ✅ Event 113603 processed successfully
#
# 📍 Processing event 255/306: 3871
#
# 🔄 Processing event 3871 (FL)...
# 🔍 Fetching episodes for event 3871...
# ✅ Found 1 episodes: [249]
# 📡 Fetching geometry for episode 249...
# ✅ Retrieved 1 geometry objects
# 🔧 Unifying 1 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 3871 geometry unified successfully
# ✅ Event 3871 processed successfully
#
# 📍 Processing event 256/306: 3837
#
# 🔄 Processing event 3837 (FL)...
# 🔍 Fetching episodes for event 3837...
# ✅ Found 1 episodes: [249]
# 📡 Fetching geometry for episode 249...
# ✅ Retrieved 1 geometry objects
# 🔧 Unifying 1 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 3837 geometry unified successfully
# ✅ Event 3837 processed successfully
#
# 📍 Processing event 257/306: 83983
#
# 🔄 Processing event 83983 (EQ)...
# 🔍 Fetching episodes for event 83983...
# ✅ Found 1 episodes: [84308]
# 📡 Fetching geometry for episode 84308...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 83983 geometry unified successfully
# ✅ Event 83983 processed successfully
#
# 📍 Processing event 258/306: 3562
#
# 🔄 Processing event 3562 (FL)...
# 🔍 Fetching episodes for event 3562...
# ✅ Found 1 episodes: [1]
# 📡 Fetching geometry for episode 1...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 3562 geometry unified successfully
# ✅ Event 3562 processed successfully
#
# 📍 Processing event 259/306: 46904
#
# 🔄 Processing event 46904 (EQ)...
# 🔍 Fetching episodes for event 46904...
# ✅ Found 1 episodes: [46907]
# 📡 Fetching geometry for episode 46907...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 46904 geometry unified successfully
# ✅ Event 46904 processed successfully
#
# 📍 Processing event 260/306: 3220
#
# 🔄 Processing event 3220 (FL)...
# 🔍 Fetching episodes for event 3220...
# ✅ Found 1 episodes: [1]
# 📡 Fetching geometry for episode 1...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 3220 geometry unified successfully
# ✅ Event 3220 processed successfully
#
# 📍 Processing event 261/306: 1213
#
# 🔄 Processing event 1213 (EQ)...
# 🔍 Fetching episodes for event 1213...
# ✅ Found 1 episodes: [1214]
# 📡 Fetching geometry for episode 1214...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1213 geometry unified successfully
# ✅ Event 1213 processed successfully
#
# 📍 Processing event 262/306: 1094
#
# 🔄 Processing event 1094 (EQ)...
# 🔍 Fetching episodes for event 1094...
# ✅ Found 1 episodes: [1094]
# 📡 Fetching geometry for episode 1094...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1094 geometry unified successfully
# ✅ Event 1094 processed successfully
#
# 📍 Processing event 263/306: 871
#
# 🔄 Processing event 871 (EQ)...
# 🔍 Fetching episodes for event 871...
# ✅ Found 1 episodes: [871]
# 📡 Fetching geometry for episode 871...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 871 geometry unified successfully
# ✅ Event 871 processed successfully
#
# 📍 Processing event 264/306: 822
#
# 🔄 Processing event 822 (EQ)...
# 🔍 Fetching episodes for event 822...
# ✅ Found 1 episodes: [822]
# 📡 Fetching geometry for episode 822...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 822 geometry unified successfully
# ✅ Event 822 processed successfully
#
# 📍 Processing event 265/306: 604
#
# 🔄 Processing event 604 (EQ)...
# 🔍 Fetching episodes for event 604...
# ✅ Found 1 episodes: [604]
# 📡 Fetching geometry for episode 604...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 604 geometry unified successfully
# ✅ Event 604 processed successfully
#
# 📍 Processing event 266/306: 600
#
# 🔄 Processing event 600 (EQ)...
# 🔍 Fetching episodes for event 600...
# ✅ Found 1 episodes: [600]
# 📡 Fetching geometry for episode 600...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 600 geometry unified successfully
# ✅ Event 600 processed successfully
#
# 📍 Processing event 267/306: 197
#
# 🔄 Processing event 197 (EQ)...
# 🔍 Fetching episodes for event 197...
# ✅ Found 1 episodes: [197]
# 📡 Fetching geometry for episode 197...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 197 geometry unified successfully
# ✅ Event 197 processed successfully
#
# 📍 Processing event 268/306: 53
#
# 🔄 Processing event 53 (EQ)...
# 🔍 Fetching episodes for event 53...
# ✅ Found 1 episodes: [58]
# 📡 Fetching geometry for episode 58...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 53 geometry unified successfully
# ✅ Event 53 processed successfully
#
# 📍 Processing event 269/306: 1000686
#
# 🔄 Processing event 1000686 (TC)...
# 🔍 Fetching episodes for event 1000686...
# ✅ Found 1 episodes: [33]
# 📡 Fetching geometry for episode 33...
# ✅ Retrieved 73 geometry objects
# 🔧 Unifying 73 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000686 geometry unified successfully
# ✅ Event 1000686 processed successfully
#
# 📍 Processing event 270/306: 1102899
#
# 🔄 Processing event 1102899 (FL)...
# 🔍 Fetching episodes for event 1102899...
# ✅ Found 1 episodes: [3]
# 📡 Fetching geometry for episode 3...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1102899 geometry unified successfully
# ✅ Event 1102899 processed successfully
# 📋 Event 1016963 already cached
#
# 📍 Processing event 272/306: 1103339
#
# 🔄 Processing event 1103339 (FL)...
# 🔍 Fetching episodes for event 1103339...
# ✅ Found 1 episodes: [16]
# 📡 Fetching geometry for episode 16...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1103339 geometry unified successfully
# ✅ Event 1103339 processed successfully
#
# 📍 Processing event 273/306: 1023255
#
# 🔄 Processing event 1023255 (WF)...
# 🔍 Fetching episodes for event 1023255...
# ✅ Found 1 episodes: [13]
# 📡 Fetching geometry for episode 13...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1023255 geometry unified successfully
# ✅ Event 1023255 processed successfully
#
# 📍 Processing event 274/306: 1023277
#
# 🔄 Processing event 1023277 (WF)...
# 🔍 Fetching episodes for event 1023277...
# ✅ Found 1 episodes: [5]
# 📡 Fetching geometry for episode 5...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1023277 geometry unified successfully
# ✅ Event 1023277 processed successfully
#
# 📍 Processing event 275/306: 1001114
#
# 🔄 Processing event 1001114 (TC)...
# 🔍 Fetching episodes for event 1001114...
# ✅ Found 1 episodes: [15]
# 📡 Fetching geometry for episode 15...
# ✅ Retrieved 34 geometry objects
# 🔧 Unifying 34 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001114 geometry unified successfully
# ✅ Event 1001114 processed successfully
# 📋 Event 1001111 already cached
# 📋 Event 1001101 already cached
# 📋 Event 1001067 already cached
# 📋 Event 1001066 already cached
#
# 📍 Processing event 280/306: 1019285
#
# 🔄 Processing event 1019285 (WF)...
# 🔍 Fetching episodes for event 1019285...
# ✅ Found 1 episodes: [2]
# 📡 Fetching geometry for episode 2...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1019285 geometry unified successfully
# ✅ Event 1019285 processed successfully
#
# 📍 Processing event 281/306: 1001000
#
# 🔄 Processing event 1001000 (TC)...
# 🔍 Fetching episodes for event 1001000...
# ✅ Found 1 episodes: [29]
# 📡 Fetching geometry for episode 29...
# ✅ Retrieved 78 geometry objects
# 🔧 Unifying 78 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1001000 geometry unified successfully
# ✅ Event 1001000 processed successfully
#
# 📍 Processing event 282/306: 1016286
#
# 🔄 Processing event 1016286 (WF)...
# 🔍 Fetching episodes for event 1016286...
# ✅ Found 1 episodes: [1]
# 📡 Fetching geometry for episode 1...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1016286 geometry unified successfully
# ✅ Event 1016286 processed successfully
#
# 📍 Processing event 283/306: 1000923
#
# 🔄 Processing event 1000923 (TC)...
# 🔍 Fetching episodes for event 1000923...
# ✅ Found 1 episodes: [38]
# 📡 Fetching geometry for episode 38...
# ✅ Retrieved 78 geometry objects
# 🔧 Unifying 78 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000923 geometry unified successfully
# ✅ Event 1000923 processed successfully
#
# 📍 Processing event 284/306: 1000818
#
# 🔄 Processing event 1000818 (TC)...
# 🔍 Fetching episodes for event 1000818...
# ✅ Found 1 episodes: [19]
# 📡 Fetching geometry for episode 19...
# ✅ Retrieved 56 geometry objects
# 🔧 Unifying 56 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000818 geometry unified successfully
# ✅ Event 1000818 processed successfully
#
# 📍 Processing event 285/306: 1279046
#
# 🔄 Processing event 1279046 (EQ)...
# 🔍 Fetching episodes for event 1279046...
# ✅ Found 1 episodes: [1388004]
# 📡 Fetching geometry for episode 1388004...
# ✅ Retrieved 13 geometry objects
# 🔧 Unifying 13 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1279046 geometry unified successfully
# ✅ Event 1279046 processed successfully
#
# 📍 Processing event 286/306: 1000795
#
# 🔄 Processing event 1000795 (TC)...
# 🔍 Fetching episodes for event 1000795...
# ✅ Found 1 episodes: [39]
# 📡 Fetching geometry for episode 39...
# ✅ Retrieved 88 geometry objects
# 🔧 Unifying 88 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000795 geometry unified successfully
# ✅ Event 1000795 processed successfully
# 📋 Event 1014139 already cached
#
# 📍 Processing event 288/306: 1000738
#
# 🔄 Processing event 1000738 (TC)...
# 🔍 Fetching episodes for event 1000738...
# ✅ Found 1 episodes: [52]
# 📡 Fetching geometry for episode 52...
# ✅ Retrieved 114 geometry objects
# 🔧 Unifying 114 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000738 geometry unified successfully
# ✅ Event 1000738 processed successfully
# 📋 Event 1100669 already cached
# 📋 Event 1000735 already cached
# 📋 Event 1014182 already cached
# 📋 Event 1000726 already cached
#
# 📍 Processing event 293/306: 1000700
#
# 🔄 Processing event 1000700 (TC)...
# 🔍 Fetching episodes for event 1000700...
# ✅ Found 1 episodes: [33]
# 📡 Fetching geometry for episode 33...
# ✅ Retrieved 84 geometry objects
# 🔧 Unifying 84 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000700 geometry unified successfully
# ✅ Event 1000700 processed successfully
# 📋 Event 1000686 already cached
# 📋 Event 1000685 already cached
#
# 📍 Processing event 296/306: 1000588
#
# 🔄 Processing event 1000588 (TC)...
# 🔍 Fetching episodes for event 1000588...
# ✅ Found 1 episodes: [64]
# 📡 Fetching geometry for episode 64...
# ✅ Retrieved 138 geometry objects
# 🔧 Unifying 138 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000588 geometry unified successfully
# ✅ Event 1000588 processed successfully
#
# 📍 Processing event 297/306: 1183131
#
# 🔄 Processing event 1183131 (EQ)...
# 🔍 Fetching episodes for event 1183131...
# ✅ Found 1 episodes: [1265091]
# 📡 Fetching geometry for episode 1265091...
# ✅ Retrieved 15 geometry objects
# 🔧 Unifying 15 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1183131 geometry unified successfully
# ✅ Event 1183131 processed successfully
#
# 📍 Processing event 298/306: 1000517
#
# 🔄 Processing event 1000517 (TC)...
# 🔍 Fetching episodes for event 1000517...
# ✅ Found 1 episodes: [23]
# 📡 Fetching geometry for episode 23...
# ✅ Retrieved 55 geometry objects
# 🔧 Unifying 55 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000517 geometry unified successfully
# ✅ Event 1000517 processed successfully
#
# 📍 Processing event 299/306: 511
#
# 🔄 Processing event 511 (VO)...
# 🔍 Fetching episodes for event 511...
# ✅ Found 1 episodes: [1]
# 📡 Fetching geometry for episode 1...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 511 geometry unified successfully
# ✅ Event 511 processed successfully
#
# 📍 Processing event 300/306: 1000393
#
# 🔄 Processing event 1000393 (TC)...
# 🔍 Fetching episodes for event 1000393...
# ✅ Found 1 episodes: [52]
# 📡 Fetching geometry for episode 52...
# ✅ Retrieved 114 geometry objects
# 🔧 Unifying 114 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000393 geometry unified successfully
# ✅ Event 1000393 processed successfully
#
# 📍 Processing event 301/306: 1000387
#
# 🔄 Processing event 1000387 (TC)...
# 🔍 Fetching episodes for event 1000387...
# ✅ Found 1 episodes: [43]
# 📡 Fetching geometry for episode 43...
# ✅ Retrieved 91 geometry objects
# 🔧 Unifying 91 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000387 geometry unified successfully
# ✅ Event 1000387 processed successfully
#
# 📍 Processing event 302/306: 1000316
#
# 🔄 Processing event 1000316 (TC)...
# 🔍 Fetching episodes for event 1000316...
# ✅ Found 1 episodes: [47]
# 📡 Fetching geometry for episode 47...
# ✅ Retrieved 98 geometry objects
# 🔧 Unifying 98 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000316 geometry unified successfully
# ✅ Event 1000316 processed successfully
#
# 📍 Processing event 303/306: 1000203
#
# 🔄 Processing event 1000203 (TC)...
# 🔍 Fetching episodes for event 1000203...
# ✅ Found 1 episodes: [19]
# 📡 Fetching geometry for episode 19...
# ✅ Retrieved 22 geometry objects
# 🔧 Unifying 22 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1000203 geometry unified successfully
# ✅ Event 1000203 processed successfully
#
# 📍 Processing event 304/306: 33263
#
# 🔄 Processing event 33263 (TC)...
# 🔍 Fetching episodes for event 33263...
# ✅ Found 1 episodes: [31]
# 📡 Fetching geometry for episode 31...
# ✅ Retrieved 4 geometry objects
# 🔧 Unifying 4 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 33263 geometry unified successfully
# ✅ Event 33263 processed successfully
#
# 📍 Processing event 305/306: 25532
#
# 🔄 Processing event 25532 (TC)...
# 🔍 Fetching episodes for event 25532...
# ✅ Found 1 episodes: [35]
# 📡 Fetching geometry for episode 35...
# ✅ Retrieved 3 geometry objects
# 🔧 Unifying 3 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 25532 geometry unified successfully
# ✅ Event 25532 processed successfully
#
# 📍 Processing event 306/306: 1591
#
# 🔄 Processing event 1591 (EQ)...
# 🔍 Fetching episodes for event 1591...
# ✅ Found 1 episodes: [1591]
# 📡 Fetching geometry for episode 1591...
# ✅ Retrieved 2 geometry objects
# 🔧 Unifying 2 geometries...
# 🔧 Applying 10.0km buffer...
# ✅ Event 1591 geometry unified successfully
# ✅ Event 1591 processed successfully
#
# 🎯 Successfully processed 293 unique events
# ============================================================
#
# 🎯 Found 727 matching items using precise geometries
#
# 📋 Enhanced Analysis Summary
# ========================================
# 🎯 Total matches found: 727
# 👥 Unique clients affected: 31
# 🌪️  Unique events processed: 293
#
# 🌪️ Disaster types found:
#    • TC: 465
#    • DR: 50
#    • EQ: 106
#    • FL: 106
#
# 💾 Save Results
# ==============================
# Save results to files? [Y/n]: y
# JSON filename (default: enhanced_disaster_analysis_400.0km_buffer10.0km.json):
# 💾 Enhanced results saved to: enhanced_disaster_analysis_400.0km_buffer10.0km.json
# Also save as Excel file? [Y/n]: y
# Excel filename (default: enhanced_disaster_analysis_400.0km_buffer10.0km.xlsx):
# 📊 Creating Excel file: enhanced_disaster_analysis_400.0km_buffer10.0km.xlsx
# 📝 Creating 'Detailed_Matches' sheet...
# 📊 Creating 'Summary_Statistics' sheet...
# 📈 Creating 'Disaster_Types' sheet...
# 🚨 Creating 'Alert_Levels' sheet...
# 🌍 Creating 'Countries_Affected' sheet...
# 📏 Creating 'Distance_Analysis' sheet...
# 🌪️  Creating 'All_Disaster_Events' sheet...
# 🗺️  Creating 'Geometry_Summary' sheet...
# ✅ Excel file successfully created: enhanced_disaster_analysis_400.0km_buffer10.0km.xlsx
# 📊 Created 8 sheets with comprehensive analysis
# Export unified geometries as GeoJSON? [y/N]: y
# 🗺️  Geometries exported to: unified_geometries_400.0km.geojson
# Download files to local machine? [y/N]: y
# 📥 File download completed!
#
# 🎉 Enhanced analysis completed successfully!
# 💡 This analysis used precise polygon geometries for accurate distance calculations
